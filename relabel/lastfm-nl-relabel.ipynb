# %%
# Apply fairness-aware data re-label (inspired by Kamiran et al.) on lastfm-nl dataset for RecBole
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# 1. Load user profile, label interactions and plays interactions
user_df = pd.read_csv('../Post-processing/datasets/lastfm-nl/lastfm-nl.user', sep='\t')  # user_id:token, gender, age, etc.
inter_df_label = pd.read_csv('../datasets/split_datasets/lastfm-nl/lastfm-nl.train.inter', sep='\t')  # user_id:token, artist_id:token, label
inter_df_plays = pd.read_csv('../Post-processing/datasets/lastfm-nl/lastfm-nl.inter', sep='\t')  # user_id:token, artist_id:token, plays

# 2. Merge plays into train.inter
inter_df = inter_df_label.merge(
    inter_df_plays[['user_id:token', 'artist_id:token', 'plays:float']],
    how='left',
    left_on=['user_id:token', 'artist_id:token'],
    right_on=['user_id:token', 'artist_id:token']
)

# 3. Merge gender info
merged_df = inter_df.merge(
    user_df[['user_id:token', 'gender:token']],
    on='user_id:token',
    how='left'
)

merged_df.rename(columns={'gender:token': 'gender'}, inplace=True)

display(merged_df.head())
# Out:
#                               user_id:token  \
# 0  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 1  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 2  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 3  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 4  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
#
#                         artist_id:token  label:float  plays:float gender
# 0  c7e90641-f441-4801-8e4a-d09e10f452b8          1.0          166      M
# 1  41489644-58f8-47e7-a581-e24d5659baeb          1.0          458      M
# 2  609e7afd-3552-4102-9501-7611858ea320          1.0          176      M
# 3  5251b5a0-3e3b-4d07-a152-585009575310          1.0          193      M
# 4  5f6ab597-f57a-40da-be9e-adad48708203          1.0          402      M

# %%
# Count total users per gender (based on unique user-gender pairs)
user_gender_map = merged_df[['user_id:token', 'gender']].drop_duplicates()
gender_total = user_gender_map['gender'].value_counts().to_dict()
display(gender_total)
# Out:
# {'M': 7059, 'F': 1733}

# %%
# Total label=1 count per gender
print(f"Total interactions: {len(merged_df)}")
label_counts = merged_df['gender'].value_counts().to_dict()
display(label_counts)

# Compute global target ratio
target_ratio = merged_df['label:float'].mean()
print(f"\nGlobal target positive ratio (label==1): {target_ratio:.4f}")
# Out:
# Total interactions: 356414
# {'M': 287033, 'F': 69381}
# Global target positive ratio (label==1): 0.9950

# %%
label_1_counts = merged_df[merged_df['label:float'] == 1]['gender'].value_counts().to_dict()
current_male_1 = label_1_counts.get('M', 0)
current_female_1 = label_1_counts.get('F', 0)
# Compute target positive counts per gender group
target_male_1 = int(target_ratio * label_counts.get('M', 1))
target_female_1 = int(target_ratio * label_counts.get('F', 1))

flip_male_1_to_0 = abs(target_male_1 - current_male_1)
flip_female_0_to_1 = abs(target_female_1 - current_female_1)
print(f"  Target male label=1 count: {target_male_1}, current: {current_male_1}, {flip_male_1_to_0} to flip")
print(f"  Target female label=1 count: {target_female_1}, current: {current_female_1}, {flip_female_0_to_1} to flip")
# Out:
#   Target male label=1 count: 285604, current: 285760, 156 to flip
#   Target female label=1 count: 69035, current: 68880, 155 to flip

# %%
# Apply relabeling
import numpy as np

# Copy the dataframe to avoid overwriting
balanced_df = merged_df.copy()

# --- Flip male label=1 → 0: pick with lowest plays ---
male_label1 = balanced_df[(balanced_df['gender'] == 'M') & (balanced_df['label:float'] == 1)]
lowest_play_males = male_label1.nsmallest(flip_male_1_to_0, 'plays:float').index
balanced_df.loc[lowest_play_males, 'label:float'] = 0

# --- Flip female label=0 → 1: pick randomly ---
female_label0 = balanced_df[(balanced_df['gender'] == 'F') & (balanced_df['label:float'] == 0)]
flip_indices_female = np.random.choice(female_label0.index, size=flip_female_0_to_1, replace=False)
balanced_df.loc[flip_indices_female, 'label:float'] = 1

# %%
before_ratio = merged_df.groupby('gender')['label:float'].value_counts(normalize=True).unstack()
print(before_ratio)
result = balanced_df.groupby('gender')['label:float'].value_counts(normalize=True).unstack()
print("\nFinal label==1 ratio by gender:")
print(result)
# Out:
# label:float       0.0       1.0
# gender
# F            0.007221  0.992779
# M            0.004435  0.995565
#
# Final label==1 ratio by gender:
# label:float       0.0       1.0
# gender
# F            0.004987  0.995013
# M            0.004979  0.995021

# %%
# 8. Save re-sampled interaction set
import os

save_path = 'datasets/lastfm-nl/lastfm-nl.train.inter'
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# 保存
balanced_df[['user_id:token', 'artist_id:token', 'label:float']].to_csv(
    save_path,
    sep='\t',
    index=False
)
print(f"✅ Fair resampled dataset saved to {save_path}")
# Out:
# ✅ Fair resampled dataset saved to datasets/lastfm-nl/lastfm-nl.train.inter

# %%
import shutil

src_path = '../datasets/split_datasets/lastfm-nl/lastfm-nl.valid.inter'
dst_dir = 'datasets/lastfm-nl'
dst_path = os.path.join(dst_dir, 'lastfm-nl.valid.inter')

os.makedirs(dst_dir, exist_ok=True)

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")

src_path = '../datasets/split_datasets/lastfm-nl/lastfm-nl.test.inter'
dst_path = os.path.join(dst_dir, 'lastfm-nl.test.inter')

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")
# Out:
# ✅ File copied to datasets/lastfm-nl/lastfm-nl.valid.inter
# ✅ File copied to datasets/lastfm-nl/lastfm-nl.test.inter

# %%
from recbole.quick_start import run_recbole

run_recbole(config_file_list=['lastfm-nl-relabel.yaml'])
# Out:
# 10 Jun 12:27    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-930ab081-4f58-43e6-9f24-0c52d7adf2d5.json']
# 10 Jun 12:27    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'label']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 10 Jun 12:27    INFO  Saving filtered dataset into [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 12:27    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.39035486806188
# The number of items: 36078
# Average actions of items: 12.03647753416304
# The number of inters: 434240
# The sparsity of the dataset: 99.8631167529806%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 12:27    INFO  Saving split dataloaders into: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 12:27    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 12:27    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 10 Jun 12:27    INFO  BPR(
#   (user_embedding): Embedding(8793, 64)
#   (item_embedding): Embedding(36078, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 2871744
# 10 Jun 12:27    INFO  FLOPs: 128.0
# wandb: Currently logged in as: jiaqing61 (jiaqing61-tud) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/Users/huangjiaqing/Desktop/Recommender Systems/RScode/Relabel/wandb/run-20250610_122750-t5wt9vj1</code>
# Syncing run <strong><a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/t5wt9vj1' target="_blank">magic-monkey-83</a></strong> to <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud</a>
#  View run at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/t5wt9vj1' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/t5wt9vj1</a>
# 10 Jun 12:27    INFO  epoch 0 training [time: 3.13s, train loss: 241.3529]
# 10 Jun 12:28    INFO  epoch 0 evaluating [time: 11.26s, valid_score: 0.030500]
# 10 Jun 12:28    INFO  valid result:
# precision@10 : 0.0164    recall@10 : 0.0373    hit@10 : 0.1512    ndcg@10 : 0.0305    itemcoverage@10 : 0.0545    averagepopularity@10 : 1185.0535    shannonentropy@10 : 0.0016    giniindex@10 : 0.9983    tailpercentage@10 : 0.0029
# 10 Jun 12:28    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:28    INFO  epoch 1 training [time: 2.75s, train loss: 200.0739]
# 10 Jun 12:28    INFO  epoch 1 evaluating [time: 12.54s, valid_score: 0.029400]
# 10 Jun 12:28    INFO  valid result:
# precision@10 : 0.0156    recall@10 : 0.0353    hit@10 : 0.1424    ndcg@10 : 0.0294    itemcoverage@10 : 0.0094    averagepopularity@10 : 1242.647    shannonentropy@10 : 0.0072    giniindex@10 : 0.9997    tailpercentage@10 : 0.0007
# 10 Jun 12:28    INFO  epoch 2 training [time: 2.85s, train loss: 121.7005]
# 10 Jun 12:28    INFO  epoch 2 evaluating [time: 12.30s, valid_score: 0.030000]
# 10 Jun 12:28    INFO  valid result:
# precision@10 : 0.0161    recall@10 : 0.0365    hit@10 : 0.1475    ndcg@10 : 0.03    itemcoverage@10 : 0.0072    averagepopularity@10 : 1231.399    shannonentropy@10 : 0.0099    giniindex@10 : 0.9997    tailpercentage@10 : 0.0007
# 10 Jun 12:28    INFO  epoch 3 training [time: 3.20s, train loss: 91.4898]
# 10 Jun 12:28    INFO  epoch 3 evaluating [time: 11.96s, valid_score: 0.031300]
# 10 Jun 12:28    INFO  valid result:
# precision@10 : 0.0166    recall@10 : 0.0375    hit@10 : 0.1526    ndcg@10 : 0.0313    itemcoverage@10 : 0.0083    averagepopularity@10 : 1229.6258    shannonentropy@10 : 0.0089    giniindex@10 : 0.9997    tailpercentage@10 : 0.0007
# 10 Jun 12:28    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:28    INFO  epoch 4 training [time: 3.33s, train loss: 79.9097]
# 10 Jun 12:29    INFO  epoch 4 evaluating [time: 10.85s, valid_score: 0.031100]
# 10 Jun 12:29    INFO  valid result:
# precision@10 : 0.0166    recall@10 : 0.0375    hit@10 : 0.1529    ndcg@10 : 0.0311    itemcoverage@10 : 0.0083    averagepopularity@10 : 1220.9402    shannonentropy@10 : 0.0088    giniindex@10 : 0.9997    tailpercentage@10 : 0.0005
# 10 Jun 12:29    INFO  epoch 5 training [time: 2.83s, train loss: 74.0460]
# 10 Jun 12:29    INFO  epoch 5 evaluating [time: 11.64s, valid_score: 0.030700]
# 10 Jun 12:29    INFO  valid result:
# precision@10 : 0.0163    recall@10 : 0.0369    hit@10 : 0.1501    ndcg@10 : 0.0307    itemcoverage@10 : 0.0088    averagepopularity@10 : 1221.5692    shannonentropy@10 : 0.0083    giniindex@10 : 0.9997    tailpercentage@10 : 0.0006
# 10 Jun 12:29    INFO  epoch 6 training [time: 2.79s, train loss: 70.1447]
# 10 Jun 12:29    INFO  epoch 6 evaluating [time: 11.84s, valid_score: 0.033100]
# 10 Jun 12:29    INFO  valid result:
# precision@10 : 0.0174    recall@10 : 0.0396    hit@10 : 0.1604    ndcg@10 : 0.0331    itemcoverage@10 : 0.0096    averagepopularity@10 : 1208.0957    shannonentropy@10 : 0.008    giniindex@10 : 0.9996    tailpercentage@10 : 0.0008
# 10 Jun 12:29    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:29    INFO  epoch 7 training [time: 2.94s, train loss: 67.2559]
# 10 Jun 12:29    INFO  epoch 7 evaluating [time: 10.40s, valid_score: 0.032500]
# 10 Jun 12:29    INFO  valid result:
# precision@10 : 0.0176    recall@10 : 0.0398    hit@10 : 0.1625    ndcg@10 : 0.0325    itemcoverage@10 : 0.0108    averagepopularity@10 : 1183.8549    shannonentropy@10 : 0.0073    giniindex@10 : 0.9996    tailpercentage@10 : 0.0011
# 10 Jun 12:29    INFO  epoch 8 training [time: 2.70s, train loss: 64.7240]
# 10 Jun 12:30    INFO  epoch 8 evaluating [time: 11.76s, valid_score: 0.033300]
# 10 Jun 12:30    INFO  valid result:
# precision@10 : 0.0177    recall@10 : 0.0399    hit@10 : 0.1628    ndcg@10 : 0.0333    itemcoverage@10 : 0.012    averagepopularity@10 : 1162.3902    shannonentropy@10 : 0.0068    giniindex@10 : 0.9996    tailpercentage@10 : 0.0012
# 10 Jun 12:30    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:30    INFO  epoch 9 training [time: 2.84s, train loss: 62.4034]
# 10 Jun 12:30    INFO  epoch 9 evaluating [time: 10.59s, valid_score: 0.031900]
# 10 Jun 12:30    INFO  valid result:
# precision@10 : 0.0173    recall@10 : 0.0391    hit@10 : 0.16    ndcg@10 : 0.0319    itemcoverage@10 : 0.0134    averagepopularity@10 : 1146.7838    shannonentropy@10 : 0.0061    giniindex@10 : 0.9995    tailpercentage@10 : 0.0011
# 10 Jun 12:30    INFO  epoch 10 training [time: 2.61s, train loss: 60.4934]
# 10 Jun 12:30    INFO  epoch 10 evaluating [time: 10.95s, valid_score: 0.034300]
# 10 Jun 12:30    INFO  valid result:
# precision@10 : 0.018    recall@10 : 0.0408    hit@10 : 0.1665    ndcg@10 : 0.0343    itemcoverage@10 : 0.0155    averagepopularity@10 : 1120.8618    shannonentropy@10 : 0.0054    giniindex@10 : 0.9995    tailpercentage@10 : 0.0013
# 10 Jun 12:30    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:30    INFO  epoch 11 training [time: 2.66s, train loss: 58.1901]
# 10 Jun 12:30    INFO  epoch 11 evaluating [time: 11.71s, valid_score: 0.035800]
# 10 Jun 12:30    INFO  valid result:
# precision@10 : 0.019    recall@10 : 0.0432    hit@10 : 0.1744    ndcg@10 : 0.0358    itemcoverage@10 : 0.0167    averagepopularity@10 : 1140.9063    shannonentropy@10 : 0.0053    giniindex@10 : 0.9994    tailpercentage@10 : 0.0015
# 10 Jun 12:30    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:30    INFO  epoch 12 training [time: 2.57s, train loss: 56.6264]
# 10 Jun 12:30    INFO  epoch 12 evaluating [time: 11.45s, valid_score: 0.036900]
# 10 Jun 12:30    INFO  valid result:
# precision@10 : 0.0201    recall@10 : 0.0457    hit@10 : 0.1849    ndcg@10 : 0.0369    itemcoverage@10 : 0.0177    averagepopularity@10 : 1125.5182    shannonentropy@10 : 0.0051    giniindex@10 : 0.9993    tailpercentage@10 : 0.0013
# 10 Jun 12:30    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:31    INFO  epoch 13 training [time: 2.52s, train loss: 54.6838]
# 10 Jun 12:31    INFO  epoch 13 evaluating [time: 10.86s, valid_score: 0.038500]
# 10 Jun 12:31    INFO  valid result:
# precision@10 : 0.021    recall@10 : 0.0477    hit@10 : 0.1906    ndcg@10 : 0.0385    itemcoverage@10 : 0.0183    averagepopularity@10 : 1107.8076    shannonentropy@10 : 0.0051    giniindex@10 : 0.9993    tailpercentage@10 : 0.0012
# 10 Jun 12:31    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:31    INFO  epoch 14 training [time: 2.53s, train loss: 52.5942]
# 10 Jun 12:31    INFO  epoch 14 evaluating [time: 10.93s, valid_score: 0.038100]
# 10 Jun 12:31    INFO  valid result:
# precision@10 : 0.0204    recall@10 : 0.0466    hit@10 : 0.1859    ndcg@10 : 0.0381    itemcoverage@10 : 0.0191    averagepopularity@10 : 1083.4018    shannonentropy@10 : 0.005    giniindex@10 : 0.9992    tailpercentage@10 : 0.0012
# 10 Jun 12:31    INFO  epoch 15 training [time: 2.76s, train loss: 50.4499]
# 10 Jun 12:31    INFO  epoch 15 evaluating [time: 11.19s, valid_score: 0.038500]
# 10 Jun 12:31    INFO  valid result:
# precision@10 : 0.0211    recall@10 : 0.048    hit@10 : 0.1935    ndcg@10 : 0.0385    itemcoverage@10 : 0.021    averagepopularity@10 : 1075.3339    shannonentropy@10 : 0.0046    giniindex@10 : 0.9991    tailpercentage@10 : 0.0012
# 10 Jun 12:31    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:31    INFO  epoch 16 training [time: 2.99s, train loss: 48.5128]
# 10 Jun 12:31    INFO  epoch 16 evaluating [time: 10.47s, valid_score: 0.039900]
# 10 Jun 12:31    INFO  valid result:
# precision@10 : 0.0217    recall@10 : 0.0495    hit@10 : 0.1978    ndcg@10 : 0.0399    itemcoverage@10 : 0.0227    averagepopularity@10 : 1053.9215    shannonentropy@10 : 0.0044    giniindex@10 : 0.999    tailpercentage@10 : 0.0011
# 10 Jun 12:31    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:31    INFO  epoch 17 training [time: 2.54s, train loss: 46.7565]
# 10 Jun 12:32    INFO  epoch 17 evaluating [time: 10.46s, valid_score: 0.041700]
# 10 Jun 12:32    INFO  valid result:
# precision@10 : 0.023    recall@10 : 0.0523    hit@10 : 0.2078    ndcg@10 : 0.0417    itemcoverage@10 : 0.0244    averagepopularity@10 : 1029.0559    shannonentropy@10 : 0.0042    giniindex@10 : 0.9989    tailpercentage@10 : 0.0011
# 10 Jun 12:32    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:32    INFO  epoch 18 training [time: 2.53s, train loss: 45.1438]
# 10 Jun 12:32    INFO  epoch 18 evaluating [time: 10.48s, valid_score: 0.042200]
# 10 Jun 12:32    INFO  valid result:
# precision@10 : 0.0234    recall@10 : 0.0531    hit@10 : 0.2109    ndcg@10 : 0.0422    itemcoverage@10 : 0.0256    averagepopularity@10 : 1017.8277    shannonentropy@10 : 0.0041    giniindex@10 : 0.9988    tailpercentage@10 : 0.0011
# 10 Jun 12:32    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:32    INFO  epoch 19 training [time: 2.57s, train loss: 43.0859]
# 10 Jun 12:32    INFO  epoch 19 evaluating [time: 11.01s, valid_score: 0.042300]
# 10 Jun 12:32    INFO  valid result:
# precision@10 : 0.023    recall@10 : 0.0523    hit@10 : 0.2084    ndcg@10 : 0.0423    itemcoverage@10 : 0.0275    averagepopularity@10 : 1015.4135    shannonentropy@10 : 0.0039    giniindex@10 : 0.9987    tailpercentage@10 : 0.0012
# 10 Jun 12:32    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:32    INFO  epoch 20 training [time: 2.84s, train loss: 41.5324]
# 10 Jun 12:32    INFO  epoch 20 evaluating [time: 11.22s, valid_score: 0.043600]
# 10 Jun 12:32    INFO  valid result:
# precision@10 : 0.0238    recall@10 : 0.0541    hit@10 : 0.2151    ndcg@10 : 0.0436    itemcoverage@10 : 0.0284    averagepopularity@10 : 1003.7224    shannonentropy@10 : 0.0038    giniindex@10 : 0.9986    tailpercentage@10 : 0.0012
# 10 Jun 12:32    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:32    INFO  epoch 21 training [time: 2.48s, train loss: 39.9034]
# 10 Jun 12:33    INFO  epoch 21 evaluating [time: 11.28s, valid_score: 0.043900]
# 10 Jun 12:33    INFO  valid result:
# precision@10 : 0.024    recall@10 : 0.0548    hit@10 : 0.2166    ndcg@10 : 0.0439    itemcoverage@10 : 0.0299    averagepopularity@10 : 966.6763    shannonentropy@10 : 0.0037    giniindex@10 : 0.9985    tailpercentage@10 : 0.0012
# 10 Jun 12:33    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:33    INFO  epoch 22 training [time: 2.55s, train loss: 38.4243]
# 10 Jun 12:33    INFO  epoch 22 evaluating [time: 10.58s, valid_score: 0.043900]
# 10 Jun 12:33    INFO  valid result:
# precision@10 : 0.0243    recall@10 : 0.0552    hit@10 : 0.2192    ndcg@10 : 0.0439    itemcoverage@10 : 0.032    averagepopularity@10 : 969.334    shannonentropy@10 : 0.0035    giniindex@10 : 0.9983    tailpercentage@10 : 0.0012
# 10 Jun 12:33    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:33    INFO  epoch 23 training [time: 2.58s, train loss: 36.4454]
# 10 Jun 12:33    INFO  epoch 23 evaluating [time: 10.85s, valid_score: 0.043900]
# 10 Jun 12:33    INFO  valid result:
# precision@10 : 0.0236    recall@10 : 0.0538    hit@10 : 0.2145    ndcg@10 : 0.0439    itemcoverage@10 : 0.0336    averagepopularity@10 : 951.7139    shannonentropy@10 : 0.0033    giniindex@10 : 0.9982    tailpercentage@10 : 0.0011
# 10 Jun 12:33    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:33    INFO  epoch 24 training [time: 2.60s, train loss: 35.0718]
# 10 Jun 12:33    INFO  epoch 24 evaluating [time: 10.79s, valid_score: 0.044600]
# 10 Jun 12:33    INFO  valid result:
# precision@10 : 0.0241    recall@10 : 0.0548    hit@10 : 0.2195    ndcg@10 : 0.0446    itemcoverage@10 : 0.0353    averagepopularity@10 : 930.8587    shannonentropy@10 : 0.0032    giniindex@10 : 0.9981    tailpercentage@10 : 0.0012
# 10 Jun 12:33    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:33    INFO  epoch 25 training [time: 2.75s, train loss: 34.0278]
# 10 Jun 12:33    INFO  epoch 25 evaluating [time: 10.15s, valid_score: 0.047000]
# 10 Jun 12:33    INFO  valid result:
# precision@10 : 0.0254    recall@10 : 0.0577    hit@10 : 0.2309    ndcg@10 : 0.047    itemcoverage@10 : 0.0366    averagepopularity@10 : 899.4059    shannonentropy@10 : 0.0032    giniindex@10 : 0.9978    tailpercentage@10 : 0.0012
# 10 Jun 12:33    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:33    INFO  epoch 26 training [time: 2.46s, train loss: 32.4314]
# 10 Jun 12:34    INFO  epoch 26 evaluating [time: 10.18s, valid_score: 0.048600]
# 10 Jun 12:34    INFO  valid result:
# precision@10 : 0.0261    recall@10 : 0.0593    hit@10 : 0.2352    ndcg@10 : 0.0486    itemcoverage@10 : 0.0377    averagepopularity@10 : 887.081    shannonentropy@10 : 0.0032    giniindex@10 : 0.9977    tailpercentage@10 : 0.0013
# 10 Jun 12:34    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:34    INFO  epoch 27 training [time: 2.51s, train loss: 31.1207]
# 10 Jun 12:34    INFO  epoch 27 evaluating [time: 10.79s, valid_score: 0.049600]
# 10 Jun 12:34    INFO  valid result:
# precision@10 : 0.027    recall@10 : 0.0615    hit@10 : 0.2427    ndcg@10 : 0.0496    itemcoverage@10 : 0.0397    averagepopularity@10 : 883.8324    shannonentropy@10 : 0.0031    giniindex@10 : 0.9975    tailpercentage@10 : 0.0012
# 10 Jun 12:34    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:34    INFO  epoch 28 training [time: 2.49s, train loss: 30.0632]
# 10 Jun 12:34    INFO  epoch 28 evaluating [time: 10.76s, valid_score: 0.050000]
# 10 Jun 12:34    INFO  valid result:
# precision@10 : 0.0273    recall@10 : 0.0622    hit@10 : 0.2447    ndcg@10 : 0.05    itemcoverage@10 : 0.041    averagepopularity@10 : 856.5036    shannonentropy@10 : 0.003    giniindex@10 : 0.9973    tailpercentage@10 : 0.0012
# 10 Jun 12:34    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:34    INFO  epoch 29 training [time: 2.63s, train loss: 29.0230]
# 10 Jun 12:34    INFO  epoch 29 evaluating [time: 10.70s, valid_score: 0.050000]
# 10 Jun 12:34    INFO  valid result:
# precision@10 : 0.0271    recall@10 : 0.0617    hit@10 : 0.2425    ndcg@10 : 0.05    itemcoverage@10 : 0.0427    averagepopularity@10 : 839.3553    shannonentropy@10 : 0.003    giniindex@10 : 0.9971    tailpercentage@10 : 0.0012
# 10 Jun 12:34    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:34    INFO  epoch 30 training [time: 2.46s, train loss: 27.6415]
# 10 Jun 12:35    INFO  epoch 30 evaluating [time: 11.06s, valid_score: 0.051300]
# 10 Jun 12:35    INFO  valid result:
# precision@10 : 0.028    recall@10 : 0.0636    hit@10 : 0.2494    ndcg@10 : 0.0513    itemcoverage@10 : 0.044    averagepopularity@10 : 813.3619    shannonentropy@10 : 0.003    giniindex@10 : 0.9969    tailpercentage@10 : 0.0012
# 10 Jun 12:35    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:35    INFO  epoch 31 training [time: 2.50s, train loss: 26.7973]
# 10 Jun 12:35    INFO  epoch 31 evaluating [time: 10.69s, valid_score: 0.051800]
# 10 Jun 12:35    INFO  valid result:
# precision@10 : 0.0284    recall@10 : 0.0645    hit@10 : 0.2534    ndcg@10 : 0.0518    itemcoverage@10 : 0.045    averagepopularity@10 : 822.8115    shannonentropy@10 : 0.0029    giniindex@10 : 0.9968    tailpercentage@10 : 0.0013
# 10 Jun 12:35    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:35    INFO  epoch 32 training [time: 2.48s, train loss: 26.0409]
# 10 Jun 12:35    INFO  epoch 32 evaluating [time: 11.01s, valid_score: 0.052500]
# 10 Jun 12:35    INFO  valid result:
# precision@10 : 0.0284    recall@10 : 0.0645    hit@10 : 0.2533    ndcg@10 : 0.0525    itemcoverage@10 : 0.0465    averagepopularity@10 : 822.9506    shannonentropy@10 : 0.0028    giniindex@10 : 0.9967    tailpercentage@10 : 0.0013
# 10 Jun 12:35    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:35    INFO  epoch 33 training [time: 2.65s, train loss: 25.0314]
# 10 Jun 12:35    INFO  epoch 33 evaluating [time: 10.84s, valid_score: 0.053300]
# 10 Jun 12:35    INFO  valid result:
# precision@10 : 0.029    recall@10 : 0.0659    hit@10 : 0.2581    ndcg@10 : 0.0533    itemcoverage@10 : 0.0483    averagepopularity@10 : 801.2142    shannonentropy@10 : 0.0027    giniindex@10 : 0.9965    tailpercentage@10 : 0.0014
# 10 Jun 12:35    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:35    INFO  epoch 34 training [time: 2.45s, train loss: 23.8244]
# 10 Jun 12:35    INFO  epoch 34 evaluating [time: 10.15s, valid_score: 0.053100]
# 10 Jun 12:35    INFO  valid result:
# precision@10 : 0.0288    recall@10 : 0.0656    hit@10 : 0.2577    ndcg@10 : 0.0531    itemcoverage@10 : 0.0502    averagepopularity@10 : 795.354    shannonentropy@10 : 0.0027    giniindex@10 : 0.9963    tailpercentage@10 : 0.0015
# 10 Jun 12:35    INFO  epoch 35 training [time: 2.46s, train loss: 22.8472]
# 10 Jun 12:36    INFO  epoch 35 evaluating [time: 10.16s, valid_score: 0.053200]
# 10 Jun 12:36    INFO  valid result:
# precision@10 : 0.0289    recall@10 : 0.0658    hit@10 : 0.2569    ndcg@10 : 0.0532    itemcoverage@10 : 0.0518    averagepopularity@10 : 797.8203    shannonentropy@10 : 0.0026    giniindex@10 : 0.9962    tailpercentage@10 : 0.0015
# 10 Jun 12:36    INFO  epoch 36 training [time: 2.47s, train loss: 22.1529]
# 10 Jun 12:36    INFO  epoch 36 evaluating [time: 10.14s, valid_score: 0.053800]
# 10 Jun 12:36    INFO  valid result:
# precision@10 : 0.0293    recall@10 : 0.0666    hit@10 : 0.2611    ndcg@10 : 0.0538    itemcoverage@10 : 0.0534    averagepopularity@10 : 788.7482    shannonentropy@10 : 0.0025    giniindex@10 : 0.9961    tailpercentage@10 : 0.0016
# 10 Jun 12:36    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:36    INFO  epoch 37 training [time: 2.51s, train loss: 21.8923]
# 10 Jun 12:36    INFO  epoch 37 evaluating [time: 10.71s, valid_score: 0.054200]
# 10 Jun 12:36    INFO  valid result:
# precision@10 : 0.0294    recall@10 : 0.0671    hit@10 : 0.2611    ndcg@10 : 0.0542    itemcoverage@10 : 0.0555    averagepopularity@10 : 789.6284    shannonentropy@10 : 0.0024    giniindex@10 : 0.9959    tailpercentage@10 : 0.0016
# 10 Jun 12:36    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:36    INFO  epoch 38 training [time: 2.64s, train loss: 21.0707]
# 10 Jun 12:36    INFO  epoch 38 evaluating [time: 10.66s, valid_score: 0.054500]
# 10 Jun 12:36    INFO  valid result:
# precision@10 : 0.0295    recall@10 : 0.0673    hit@10 : 0.2631    ndcg@10 : 0.0545    itemcoverage@10 : 0.0578    averagepopularity@10 : 766.4619    shannonentropy@10 : 0.0024    giniindex@10 : 0.9955    tailpercentage@10 : 0.0016
# 10 Jun 12:36    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:36    INFO  epoch 39 training [time: 2.51s, train loss: 20.2141]
# 10 Jun 12:36    INFO  epoch 39 evaluating [time: 10.68s, valid_score: 0.055300]
# 10 Jun 12:36    INFO  valid result:
# precision@10 : 0.0303    recall@10 : 0.0689    hit@10 : 0.2684    ndcg@10 : 0.0553    itemcoverage@10 : 0.0593    averagepopularity@10 : 759.3867    shannonentropy@10 : 0.0023    giniindex@10 : 0.9954    tailpercentage@10 : 0.0016
# 10 Jun 12:36    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:37    INFO  epoch 40 training [time: 2.51s, train loss: 19.5478]
# 10 Jun 12:37    INFO  epoch 40 evaluating [time: 10.70s, valid_score: 0.055500]
# 10 Jun 12:37    INFO  valid result:
# precision@10 : 0.0302    recall@10 : 0.0687    hit@10 : 0.2689    ndcg@10 : 0.0555    itemcoverage@10 : 0.0611    averagepopularity@10 : 739.3514    shannonentropy@10 : 0.0023    giniindex@10 : 0.9952    tailpercentage@10 : 0.0018
# 10 Jun 12:37    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:37    INFO  epoch 41 training [time: 2.44s, train loss: 18.9469]
# 10 Jun 12:37    INFO  epoch 41 evaluating [time: 10.70s, valid_score: 0.055000]
# 10 Jun 12:37    INFO  valid result:
# precision@10 : 0.0302    recall@10 : 0.0687    hit@10 : 0.2656    ndcg@10 : 0.055    itemcoverage@10 : 0.0638    averagepopularity@10 : 732.133    shannonentropy@10 : 0.0022    giniindex@10 : 0.9949    tailpercentage@10 : 0.0019
# 10 Jun 12:37    INFO  epoch 42 training [time: 2.63s, train loss: 18.4997]
# 10 Jun 12:37    INFO  epoch 42 evaluating [time: 10.79s, valid_score: 0.055600]
# 10 Jun 12:37    INFO  valid result:
# precision@10 : 0.0301    recall@10 : 0.0686    hit@10 : 0.2679    ndcg@10 : 0.0556    itemcoverage@10 : 0.0654    averagepopularity@10 : 744.6449    shannonentropy@10 : 0.0021    giniindex@10 : 0.9948    tailpercentage@10 : 0.002
# 10 Jun 12:37    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:37    INFO  epoch 43 training [time: 2.50s, train loss: 17.6002]
# 10 Jun 12:37    INFO  epoch 43 evaluating [time: 10.60s, valid_score: 0.055900]
# 10 Jun 12:37    INFO  valid result:
# precision@10 : 0.0301    recall@10 : 0.0687    hit@10 : 0.266    ndcg@10 : 0.0559    itemcoverage@10 : 0.0671    averagepopularity@10 : 749.4312    shannonentropy@10 : 0.0021    giniindex@10 : 0.9948    tailpercentage@10 : 0.002
# 10 Jun 12:37    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:37    INFO  epoch 44 training [time: 2.50s, train loss: 17.3601]
# 10 Jun 12:38    INFO  epoch 44 evaluating [time: 10.14s, valid_score: 0.055800]
# 10 Jun 12:38    INFO  valid result:
# precision@10 : 0.0301    recall@10 : 0.0686    hit@10 : 0.2674    ndcg@10 : 0.0558    itemcoverage@10 : 0.0694    averagepopularity@10 : 743.4709    shannonentropy@10 : 0.002    giniindex@10 : 0.9946    tailpercentage@10 : 0.002
# 10 Jun 12:38    INFO  epoch 45 training [time: 2.51s, train loss: 16.8094]
# 10 Jun 12:38    INFO  epoch 45 evaluating [time: 10.72s, valid_score: 0.056100]
# 10 Jun 12:38    INFO  valid result:
# precision@10 : 0.0304    recall@10 : 0.0692    hit@10 : 0.2687    ndcg@10 : 0.0561    itemcoverage@10 : 0.0711    averagepopularity@10 : 738.0804    shannonentropy@10 : 0.002    giniindex@10 : 0.9943    tailpercentage@10 : 0.0022
# 10 Jun 12:38    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:38    INFO  epoch 46 training [time: 2.68s, train loss: 16.3313]
# 10 Jun 12:38    INFO  epoch 46 evaluating [time: 10.42s, valid_score: 0.057200]
# 10 Jun 12:38    INFO  valid result:
# precision@10 : 0.0311    recall@10 : 0.0707    hit@10 : 0.2739    ndcg@10 : 0.0572    itemcoverage@10 : 0.0728    averagepopularity@10 : 726.6425    shannonentropy@10 : 0.002    giniindex@10 : 0.994    tailpercentage@10 : 0.0023
# 10 Jun 12:38    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:38    INFO  epoch 47 training [time: 2.50s, train loss: 15.7906]
# 10 Jun 12:38    INFO  epoch 47 evaluating [time: 13.47s, valid_score: 0.057200]
# 10 Jun 12:38    INFO  valid result:
# precision@10 : 0.0311    recall@10 : 0.0709    hit@10 : 0.2757    ndcg@10 : 0.0572    itemcoverage@10 : 0.0751    averagepopularity@10 : 721.3251    shannonentropy@10 : 0.0019    giniindex@10 : 0.9937    tailpercentage@10 : 0.0024
# 10 Jun 12:38    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:38    INFO  epoch 48 training [time: 2.82s, train loss: 15.1524]
# 10 Jun 12:38    INFO  epoch 48 evaluating [time: 10.86s, valid_score: 0.057600]
# 10 Jun 12:38    INFO  valid result:
# precision@10 : 0.0317    recall@10 : 0.0722    hit@10 : 0.2787    ndcg@10 : 0.0576    itemcoverage@10 : 0.0768    averagepopularity@10 : 721.4783    shannonentropy@10 : 0.0019    giniindex@10 : 0.9936    tailpercentage@10 : 0.0025
# 10 Jun 12:38    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:39    INFO  epoch 49 training [time: 2.51s, train loss: 14.9477]
# 10 Jun 12:39    INFO  epoch 49 evaluating [time: 10.79s, valid_score: 0.056700]
# 10 Jun 12:39    INFO  valid result:
# precision@10 : 0.0309    recall@10 : 0.0705    hit@10 : 0.2731    ndcg@10 : 0.0567    itemcoverage@10 : 0.0781    averagepopularity@10 : 718.0366    shannonentropy@10 : 0.0019    giniindex@10 : 0.9934    tailpercentage@10 : 0.0025
# 10 Jun 12:39    INFO  epoch 50 training [time: 2.70s, train loss: 14.6107]
# 10 Jun 12:39    INFO  epoch 50 evaluating [time: 11.34s, valid_score: 0.056900]
# 10 Jun 12:39    INFO  valid result:
# precision@10 : 0.0312    recall@10 : 0.0711    hit@10 : 0.2751    ndcg@10 : 0.0569    itemcoverage@10 : 0.0799    averagepopularity@10 : 711.1097    shannonentropy@10 : 0.0018    giniindex@10 : 0.9933    tailpercentage@10 : 0.0026
# 10 Jun 12:39    INFO  epoch 51 training [time: 2.74s, train loss: 14.2493]
# 10 Jun 12:39    INFO  epoch 51 evaluating [time: 10.89s, valid_score: 0.058300]
# 10 Jun 12:39    INFO  valid result:
# precision@10 : 0.0319    recall@10 : 0.0726    hit@10 : 0.2803    ndcg@10 : 0.0583    itemcoverage@10 : 0.0827    averagepopularity@10 : 692.7107    shannonentropy@10 : 0.0018    giniindex@10 : 0.9928    tailpercentage@10 : 0.0026
# 10 Jun 12:39    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:39    INFO  epoch 52 training [time: 2.45s, train loss: 13.8718]
# 10 Jun 12:39    INFO  epoch 52 evaluating [time: 10.71s, valid_score: 0.058000]
# 10 Jun 12:39    INFO  valid result:
# precision@10 : 0.0321    recall@10 : 0.0731    hit@10 : 0.2814    ndcg@10 : 0.058    itemcoverage@10 : 0.084    averagepopularity@10 : 698.719    shannonentropy@10 : 0.0018    giniindex@10 : 0.9927    tailpercentage@10 : 0.0028
# 10 Jun 12:39    INFO  epoch 53 training [time: 2.51s, train loss: 13.4571]
# 10 Jun 12:40    INFO  epoch 53 evaluating [time: 10.63s, valid_score: 0.057800]
# 10 Jun 12:40    INFO  valid result:
# precision@10 : 0.0321    recall@10 : 0.0729    hit@10 : 0.2813    ndcg@10 : 0.0578    itemcoverage@10 : 0.0865    averagepopularity@10 : 680.0508    shannonentropy@10 : 0.0017    giniindex@10 : 0.9924    tailpercentage@10 : 0.003
# 10 Jun 12:40    INFO  epoch 54 training [time: 2.45s, train loss: 13.2879]
# 10 Jun 12:40    INFO  epoch 54 evaluating [time: 10.14s, valid_score: 0.058100]
# 10 Jun 12:40    INFO  valid result:
# precision@10 : 0.0317    recall@10 : 0.0722    hit@10 : 0.28    ndcg@10 : 0.0581    itemcoverage@10 : 0.0881    averagepopularity@10 : 679.4787    shannonentropy@10 : 0.0017    giniindex@10 : 0.9923    tailpercentage@10 : 0.0031
# 10 Jun 12:40    INFO  epoch 55 training [time: 2.66s, train loss: 12.7406]
# 10 Jun 12:40    INFO  epoch 55 evaluating [time: 10.81s, valid_score: 0.058200]
# 10 Jun 12:40    INFO  valid result:
# precision@10 : 0.0322    recall@10 : 0.0733    hit@10 : 0.2812    ndcg@10 : 0.0582    itemcoverage@10 : 0.0901    averagepopularity@10 : 677.5125    shannonentropy@10 : 0.0017    giniindex@10 : 0.992    tailpercentage@10 : 0.0033
# 10 Jun 12:40    INFO  epoch 56 training [time: 2.53s, train loss: 12.5342]
# 10 Jun 12:40    INFO  epoch 56 evaluating [time: 11.02s, valid_score: 0.058500]
# 10 Jun 12:40    INFO  valid result:
# precision@10 : 0.0323    recall@10 : 0.0736    hit@10 : 0.282    ndcg@10 : 0.0585    itemcoverage@10 : 0.093    averagepopularity@10 : 670.5665    shannonentropy@10 : 0.0016    giniindex@10 : 0.9917    tailpercentage@10 : 0.0033
# 10 Jun 12:40    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:40    INFO  epoch 57 training [time: 2.63s, train loss: 12.2073]
# 10 Jun 12:40    INFO  epoch 57 evaluating [time: 10.34s, valid_score: 0.058800]
# 10 Jun 12:40    INFO  valid result:
# precision@10 : 0.0324    recall@10 : 0.0741    hit@10 : 0.2843    ndcg@10 : 0.0588    itemcoverage@10 : 0.0932    averagepopularity@10 : 673.6402    shannonentropy@10 : 0.0016    giniindex@10 : 0.9916    tailpercentage@10 : 0.0035
# 10 Jun 12:40    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:41    INFO  epoch 58 training [time: 2.53s, train loss: 11.6770]
# 10 Jun 12:41    INFO  epoch 58 evaluating [time: 10.86s, valid_score: 0.058500]
# 10 Jun 12:41    INFO  valid result:
# precision@10 : 0.0322    recall@10 : 0.0734    hit@10 : 0.2836    ndcg@10 : 0.0585    itemcoverage@10 : 0.0948    averagepopularity@10 : 678.5701    shannonentropy@10 : 0.0016    giniindex@10 : 0.9914    tailpercentage@10 : 0.0037
# 10 Jun 12:41    INFO  epoch 59 training [time: 2.60s, train loss: 11.7068]
# 10 Jun 12:41    INFO  epoch 59 evaluating [time: 10.35s, valid_score: 0.059100]
# 10 Jun 12:41    INFO  valid result:
# precision@10 : 0.0325    recall@10 : 0.074    hit@10 : 0.2831    ndcg@10 : 0.0591    itemcoverage@10 : 0.0969    averagepopularity@10 : 661.5183    shannonentropy@10 : 0.0016    giniindex@10 : 0.9912    tailpercentage@10 : 0.0039
# 10 Jun 12:41    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:41    INFO  epoch 60 training [time: 2.76s, train loss: 11.4554]
# 10 Jun 12:41    INFO  epoch 60 evaluating [time: 10.46s, valid_score: 0.059600]
# 10 Jun 12:41    INFO  valid result:
# precision@10 : 0.0324    recall@10 : 0.074    hit@10 : 0.2843    ndcg@10 : 0.0596    itemcoverage@10 : 0.099    averagepopularity@10 : 657.427    shannonentropy@10 : 0.0016    giniindex@10 : 0.9909    tailpercentage@10 : 0.0041
# 10 Jun 12:41    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:41    INFO  epoch 61 training [time: 2.60s, train loss: 11.2423]
# 10 Jun 12:41    INFO  epoch 61 evaluating [time: 10.84s, valid_score: 0.059600]
# 10 Jun 12:41    INFO  valid result:
# precision@10 : 0.0328    recall@10 : 0.0749    hit@10 : 0.288    ndcg@10 : 0.0596    itemcoverage@10 : 0.1007    averagepopularity@10 : 653.3323    shannonentropy@10 : 0.0015    giniindex@10 : 0.9907    tailpercentage@10 : 0.0042
# 10 Jun 12:41    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:41    INFO  epoch 62 training [time: 2.56s, train loss: 10.9572]
# 10 Jun 12:42    INFO  epoch 62 evaluating [time: 10.90s, valid_score: 0.059900]
# 10 Jun 12:42    INFO  valid result:
# precision@10 : 0.0331    recall@10 : 0.0753    hit@10 : 0.2878    ndcg@10 : 0.0599    itemcoverage@10 : 0.1025    averagepopularity@10 : 653.6327    shannonentropy@10 : 0.0015    giniindex@10 : 0.9904    tailpercentage@10 : 0.0043
# 10 Jun 12:42    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:42    INFO  epoch 63 training [time: 2.80s, train loss: 11.0810]
# 10 Jun 12:42    INFO  epoch 63 evaluating [time: 10.96s, valid_score: 0.060000]
# 10 Jun 12:42    INFO  valid result:
# precision@10 : 0.0334    recall@10 : 0.076    hit@10 : 0.2888    ndcg@10 : 0.06    itemcoverage@10 : 0.1052    averagepopularity@10 : 641.6843    shannonentropy@10 : 0.0015    giniindex@10 : 0.9901    tailpercentage@10 : 0.0046
# 10 Jun 12:42    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:42    INFO  epoch 64 training [time: 2.66s, train loss: 10.8242]
# 10 Jun 12:42    INFO  epoch 64 evaluating [time: 10.37s, valid_score: 0.059800]
# 10 Jun 12:42    INFO  valid result:
# precision@10 : 0.033    recall@10 : 0.0751    hit@10 : 0.2875    ndcg@10 : 0.0598    itemcoverage@10 : 0.1073    averagepopularity@10 : 623.8489    shannonentropy@10 : 0.0015    giniindex@10 : 0.9898    tailpercentage@10 : 0.0047
# 10 Jun 12:42    INFO  epoch 65 training [time: 2.61s, train loss: 10.4472]
# 10 Jun 12:42    INFO  epoch 65 evaluating [time: 11.15s, valid_score: 0.060100]
# 10 Jun 12:42    INFO  valid result:
# precision@10 : 0.0332    recall@10 : 0.0756    hit@10 : 0.2908    ndcg@10 : 0.0601    itemcoverage@10 : 0.109    averagepopularity@10 : 620.221    shannonentropy@10 : 0.0014    giniindex@10 : 0.9895    tailpercentage@10 : 0.0049
# 10 Jun 12:42    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:42    INFO  epoch 66 training [time: 2.58s, train loss: 10.1949]
# 10 Jun 12:43    INFO  epoch 66 evaluating [time: 10.43s, valid_score: 0.060200]
# 10 Jun 12:43    INFO  valid result:
# precision@10 : 0.0332    recall@10 : 0.0758    hit@10 : 0.2884    ndcg@10 : 0.0602    itemcoverage@10 : 0.1121    averagepopularity@10 : 615.8203    shannonentropy@10 : 0.0014    giniindex@10 : 0.9891    tailpercentage@10 : 0.0051
# 10 Jun 12:43    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:43    INFO  epoch 67 training [time: 2.54s, train loss: 9.9753]
# 10 Jun 12:43    INFO  epoch 67 evaluating [time: 10.92s, valid_score: 0.060700]
# 10 Jun 12:43    INFO  valid result:
# precision@10 : 0.0335    recall@10 : 0.0764    hit@10 : 0.2903    ndcg@10 : 0.0607    itemcoverage@10 : 0.1144    averagepopularity@10 : 617.3832    shannonentropy@10 : 0.0014    giniindex@10 : 0.9888    tailpercentage@10 : 0.0052
# 10 Jun 12:43    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:43    INFO  epoch 68 training [time: 2.61s, train loss: 9.6646]
# 10 Jun 12:43    INFO  epoch 68 evaluating [time: 10.96s, valid_score: 0.060200]
# 10 Jun 12:43    INFO  valid result:
# precision@10 : 0.0333    recall@10 : 0.0757    hit@10 : 0.2902    ndcg@10 : 0.0602    itemcoverage@10 : 0.117    averagepopularity@10 : 613.1436    shannonentropy@10 : 0.0014    giniindex@10 : 0.9884    tailpercentage@10 : 0.0056
# 10 Jun 12:43    INFO  epoch 69 training [time: 2.66s, train loss: 9.5531]
# 10 Jun 12:43    INFO  epoch 69 evaluating [time: 10.37s, valid_score: 0.060300]
# 10 Jun 12:43    INFO  valid result:
# precision@10 : 0.0335    recall@10 : 0.0761    hit@10 : 0.2907    ndcg@10 : 0.0603    itemcoverage@10 : 0.1176    averagepopularity@10 : 623.679    shannonentropy@10 : 0.0014    giniindex@10 : 0.9884    tailpercentage@10 : 0.0057
# 10 Jun 12:43    INFO  epoch 70 training [time: 2.55s, train loss: 9.4415]
# 10 Jun 12:43    INFO  epoch 70 evaluating [time: 10.35s, valid_score: 0.060600]
# 10 Jun 12:43    INFO  valid result:
# precision@10 : 0.0337    recall@10 : 0.0767    hit@10 : 0.2925    ndcg@10 : 0.0606    itemcoverage@10 : 0.1199    averagepopularity@10 : 612.4064    shannonentropy@10 : 0.0013    giniindex@10 : 0.9881    tailpercentage@10 : 0.0056
# 10 Jun 12:43    INFO  epoch 71 training [time: 2.58s, train loss: 9.3235]
# 10 Jun 12:44    INFO  epoch 71 evaluating [time: 10.91s, valid_score: 0.061200]
# 10 Jun 12:44    INFO  valid result:
# precision@10 : 0.034    recall@10 : 0.0775    hit@10 : 0.2955    ndcg@10 : 0.0612    itemcoverage@10 : 0.1219    averagepopularity@10 : 605.0235    shannonentropy@10 : 0.0013    giniindex@10 : 0.9878    tailpercentage@10 : 0.0059
# 10 Jun 12:44    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:44    INFO  epoch 72 training [time: 2.58s, train loss: 9.1783]
# 10 Jun 12:44    INFO  epoch 72 evaluating [time: 10.82s, valid_score: 0.061000]
# 10 Jun 12:44    INFO  valid result:
# precision@10 : 0.034    recall@10 : 0.0774    hit@10 : 0.2972    ndcg@10 : 0.061    itemcoverage@10 : 0.1245    averagepopularity@10 : 607.995    shannonentropy@10 : 0.0013    giniindex@10 : 0.9876    tailpercentage@10 : 0.0062
# 10 Jun 12:44    INFO  epoch 73 training [time: 2.75s, train loss: 8.9404]
# 10 Jun 12:44    INFO  epoch 73 evaluating [time: 11.36s, valid_score: 0.061300]
# 10 Jun 12:44    INFO  valid result:
# precision@10 : 0.0341    recall@10 : 0.0778    hit@10 : 0.296    ndcg@10 : 0.0613    itemcoverage@10 : 0.1264    averagepopularity@10 : 612.2411    shannonentropy@10 : 0.0013    giniindex@10 : 0.9873    tailpercentage@10 : 0.0062
# 10 Jun 12:44    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:44    INFO  epoch 74 training [time: 2.63s, train loss: 8.7317]
# 10 Jun 12:44    INFO  epoch 74 evaluating [time: 10.23s, valid_score: 0.061500]
# 10 Jun 12:44    INFO  valid result:
# precision@10 : 0.0342    recall@10 : 0.0779    hit@10 : 0.2994    ndcg@10 : 0.0615    itemcoverage@10 : 0.1286    averagepopularity@10 : 611.1241    shannonentropy@10 : 0.0013    giniindex@10 : 0.987    tailpercentage@10 : 0.0064
# 10 Jun 12:44    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:44    INFO  epoch 75 training [time: 2.55s, train loss: 8.6366]
# 10 Jun 12:45    INFO  epoch 75 evaluating [time: 10.94s, valid_score: 0.061600]
# 10 Jun 12:45    INFO  valid result:
# precision@10 : 0.0344    recall@10 : 0.0783    hit@10 : 0.2982    ndcg@10 : 0.0616    itemcoverage@10 : 0.1313    averagepopularity@10 : 608.628    shannonentropy@10 : 0.0012    giniindex@10 : 0.9866    tailpercentage@10 : 0.0067
# 10 Jun 12:45    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:45    INFO  epoch 76 training [time: 2.54s, train loss: 8.4399]
# 10 Jun 12:45    INFO  epoch 76 evaluating [time: 11.20s, valid_score: 0.061500]
# 10 Jun 12:45    INFO  valid result:
# precision@10 : 0.0344    recall@10 : 0.0783    hit@10 : 0.2983    ndcg@10 : 0.0615    itemcoverage@10 : 0.1329    averagepopularity@10 : 606.0503    shannonentropy@10 : 0.0012    giniindex@10 : 0.9864    tailpercentage@10 : 0.0068
# 10 Jun 12:45    INFO  epoch 77 training [time: 2.73s, train loss: 8.2977]
# 10 Jun 12:45    INFO  epoch 77 evaluating [time: 10.39s, valid_score: 0.061700]
# 10 Jun 12:45    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0789    hit@10 : 0.3005    ndcg@10 : 0.0617    itemcoverage@10 : 0.1342    averagepopularity@10 : 605.4811    shannonentropy@10 : 0.0012    giniindex@10 : 0.9862    tailpercentage@10 : 0.0069
# 10 Jun 12:45    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:45    INFO  epoch 78 training [time: 2.69s, train loss: 8.2377]
# 10 Jun 12:45    INFO  epoch 78 evaluating [time: 12.95s, valid_score: 0.061500]
# 10 Jun 12:45    INFO  valid result:
# precision@10 : 0.0348    recall@10 : 0.0793    hit@10 : 0.3025    ndcg@10 : 0.0615    itemcoverage@10 : 0.137    averagepopularity@10 : 600.8861    shannonentropy@10 : 0.0012    giniindex@10 : 0.9857    tailpercentage@10 : 0.0072
# 10 Jun 12:45    INFO  epoch 79 training [time: 3.48s, train loss: 8.3545]
# 10 Jun 12:46    INFO  epoch 79 evaluating [time: 13.32s, valid_score: 0.061600]
# 10 Jun 12:46    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0789    hit@10 : 0.3012    ndcg@10 : 0.0616    itemcoverage@10 : 0.1398    averagepopularity@10 : 592.3563    shannonentropy@10 : 0.0012    giniindex@10 : 0.9852    tailpercentage@10 : 0.0074
# 10 Jun 12:46    INFO  epoch 80 training [time: 3.03s, train loss: 8.0058]
# 10 Jun 12:46    INFO  epoch 80 evaluating [time: 10.70s, valid_score: 0.061700]
# 10 Jun 12:46    INFO  valid result:
# precision@10 : 0.0345    recall@10 : 0.0787    hit@10 : 0.2985    ndcg@10 : 0.0617    itemcoverage@10 : 0.1418    averagepopularity@10 : 595.6149    shannonentropy@10 : 0.0012    giniindex@10 : 0.9848    tailpercentage@10 : 0.0078
# 10 Jun 12:46    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:46    INFO  epoch 81 training [time: 2.73s, train loss: 7.8482]
# 10 Jun 12:46    INFO  epoch 81 evaluating [time: 12.04s, valid_score: 0.062300]
# 10 Jun 12:46    INFO  valid result:
# precision@10 : 0.0348    recall@10 : 0.0792    hit@10 : 0.3007    ndcg@10 : 0.0623    itemcoverage@10 : 0.144    averagepopularity@10 : 599.6047    shannonentropy@10 : 0.0011    giniindex@10 : 0.9846    tailpercentage@10 : 0.0081
# 10 Jun 12:46    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:46    INFO  epoch 82 training [time: 2.89s, train loss: 7.7886]
# 10 Jun 12:46    INFO  epoch 82 evaluating [time: 10.47s, valid_score: 0.061700]
# 10 Jun 12:46    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0786    hit@10 : 0.2986    ndcg@10 : 0.0617    itemcoverage@10 : 0.146    averagepopularity@10 : 596.1505    shannonentropy@10 : 0.0011    giniindex@10 : 0.9843    tailpercentage@10 : 0.0083
# 10 Jun 12:46    INFO  epoch 83 training [time: 2.65s, train loss: 7.6557]
# 10 Jun 12:46    INFO  epoch 83 evaluating [time: 11.31s, valid_score: 0.062000]
# 10 Jun 12:46    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0788    hit@10 : 0.3012    ndcg@10 : 0.062    itemcoverage@10 : 0.1477    averagepopularity@10 : 592.9185    shannonentropy@10 : 0.0011    giniindex@10 : 0.9839    tailpercentage@10 : 0.0083
# 10 Jun 12:46    INFO  epoch 84 training [time: 2.66s, train loss: 7.6100]
# 10 Jun 12:47    INFO  epoch 84 evaluating [time: 11.36s, valid_score: 0.062200]
# 10 Jun 12:47    INFO  valid result:
# precision@10 : 0.0348    recall@10 : 0.0793    hit@10 : 0.3031    ndcg@10 : 0.0622    itemcoverage@10 : 0.1494    averagepopularity@10 : 590.4553    shannonentropy@10 : 0.0011    giniindex@10 : 0.9836    tailpercentage@10 : 0.0087
# 10 Jun 12:47    INFO  epoch 85 training [time: 2.67s, train loss: 7.4576]
# 10 Jun 12:47    INFO  epoch 85 evaluating [time: 10.44s, valid_score: 0.062100]
# 10 Jun 12:47    INFO  valid result:
# precision@10 : 0.0348    recall@10 : 0.0793    hit@10 : 0.3028    ndcg@10 : 0.0621    itemcoverage@10 : 0.1515    averagepopularity@10 : 589.9818    shannonentropy@10 : 0.0011    giniindex@10 : 0.9834    tailpercentage@10 : 0.0088
# 10 Jun 12:47    INFO  epoch 86 training [time: 2.76s, train loss: 7.2834]
# 10 Jun 12:47    INFO  epoch 86 evaluating [time: 11.43s, valid_score: 0.062000]
# 10 Jun 12:47    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0788    hit@10 : 0.2998    ndcg@10 : 0.062    itemcoverage@10 : 0.1514    averagepopularity@10 : 583.9184    shannonentropy@10 : 0.0011    giniindex@10 : 0.9835    tailpercentage@10 : 0.0088
# 10 Jun 12:47    INFO  epoch 87 training [time: 2.53s, train loss: 7.2264]
# 10 Jun 12:47    INFO  epoch 87 evaluating [time: 11.89s, valid_score: 0.061900]
# 10 Jun 12:47    INFO  valid result:
# precision@10 : 0.0348    recall@10 : 0.0794    hit@10 : 0.3019    ndcg@10 : 0.0619    itemcoverage@10 : 0.1538    averagepopularity@10 : 573.4858    shannonentropy@10 : 0.0011    giniindex@10 : 0.9831    tailpercentage@10 : 0.0091
# 10 Jun 12:47    INFO  epoch 88 training [time: 2.59s, train loss: 7.3042]
# 10 Jun 12:48    INFO  epoch 88 evaluating [time: 11.04s, valid_score: 0.061600]
# 10 Jun 12:48    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0789    hit@10 : 0.3008    ndcg@10 : 0.0616    itemcoverage@10 : 0.157    averagepopularity@10 : 573.0423    shannonentropy@10 : 0.0011    giniindex@10 : 0.9824    tailpercentage@10 : 0.0095
# 10 Jun 12:48    INFO  epoch 89 training [time: 2.57s, train loss: 6.9769]
# 10 Jun 12:48    INFO  epoch 89 evaluating [time: 10.42s, valid_score: 0.061600]
# 10 Jun 12:48    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0788    hit@10 : 0.3    ndcg@10 : 0.0616    itemcoverage@10 : 0.1584    averagepopularity@10 : 574.0889    shannonentropy@10 : 0.0011    giniindex@10 : 0.9821    tailpercentage@10 : 0.0097
# 10 Jun 12:48    INFO  epoch 90 training [time: 2.72s, train loss: 7.0019]
# 10 Jun 12:48    INFO  epoch 90 evaluating [time: 10.49s, valid_score: 0.061700]
# 10 Jun 12:48    INFO  valid result:
# precision@10 : 0.035    recall@10 : 0.0797    hit@10 : 0.3032    ndcg@10 : 0.0617    itemcoverage@10 : 0.1602    averagepopularity@10 : 576.798    shannonentropy@10 : 0.0011    giniindex@10 : 0.9819    tailpercentage@10 : 0.0098
# 10 Jun 12:48    INFO  epoch 91 training [time: 2.54s, train loss: 6.9076]
# 10 Jun 12:48    INFO  epoch 91 evaluating [time: 10.41s, valid_score: 0.061200]
# 10 Jun 12:48    INFO  valid result:
# precision@10 : 0.0348    recall@10 : 0.0795    hit@10 : 0.302    ndcg@10 : 0.0612    itemcoverage@10 : 0.1626    averagepopularity@10 : 564.8702    shannonentropy@10 : 0.001    giniindex@10 : 0.9814    tailpercentage@10 : 0.0099
# 10 Jun 12:48    INFO  epoch 92 training [time: 2.52s, train loss: 6.8638]
# 10 Jun 12:48    INFO  epoch 92 evaluating [time: 10.40s, valid_score: 0.061100]
# 10 Jun 12:48    INFO  valid result:
# precision@10 : 0.0347    recall@10 : 0.0792    hit@10 : 0.3008    ndcg@10 : 0.0611    itemcoverage@10 : 0.1651    averagepopularity@10 : 560.9612    shannonentropy@10 : 0.001    giniindex@10 : 0.981    tailpercentage@10 : 0.01
# 10 Jun 12:48    INFO  Finished training, best eval result in epoch 81
# 10 Jun 12:48    INFO  Loading model structure and parameters from checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth
# 10 Jun 12:49    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     4.60 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.59 G/16.00 G |
# +-------------+----------------+
# 10 Jun 12:49    INFO  best valid : OrderedDict([('precision@10', 0.0348), ('recall@10', 0.0792), ('hit@10', 0.3007), ('ndcg@10', 0.0623), ('itemcoverage@10', 0.144), ('averagepopularity@10', 599.6047), ('shannonentropy@10', 0.0011), ('giniindex@10', 0.9846), ('tailpercentage@10', 0.0081)])
# 10 Jun 12:49    INFO  test result: OrderedDict([('precision@10', 0.0345), ('recall@10', 0.0785), ('hit@10', 0.2979), ('ndcg@10', 0.0613), ('itemcoverage@10', 0.144), ('averagepopularity@10', 599.6047), ('shannonentropy@10', 0.0011), ('giniindex@10', 0.9846), ('tailpercentage@10', 0.0081)])
# {'best_valid_score': 0.0623,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('precision@10', 0.0348),
#               ('recall@10', 0.0792),
#               ('hit@10', 0.3007),
#               ('ndcg@10', 0.0623),
#               ('itemcoverage@10', 0.144),
#               ('averagepopularity@10', 599.6047),
#               ('shannonentropy@10', 0.0011),
#               ('giniindex@10', 0.9846),
#               ('tailpercentage@10', 0.0081)]),
#  'test_result': OrderedDict([('precision@10', 0.0345),
#               ('recall@10', 0.0785),
#               ('hit@10', 0.2979),
#               ('ndcg@10', 0.0613),
#               ('itemcoverage@10', 0.144),
#               ('averagepopularity@10', 599.6047),
#               ('shannonentropy@10', 0.0011),
#               ('giniindex@10', 0.9846),
#               ('tailpercentage@10', 0.0081)])}

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd
import numpy as np

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_12-27-51.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series

uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=10, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]
score_lists = [row.cpu().tolist() for row in topk_scores]

# load gender information
user_df = pd.read_csv('../Post-processing/datasets/lastfm-nl/lastfm-nl.user', sep='\t')
user_df['user_id:token'] = user_df['user_id:token'].astype(str)
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'gender': [user2gender.get(uid, 'unknown') for uid in external_user_list],
    'topk_items': [','.join(items) for items in external_item_lists],
    'topk_scores': [','.join([f'{s:.4f}' for s in scores]) for scores in score_lists]
})
display(df.head())
print(df.nunique())
df.to_csv('../rank_results/lastfm-nl/lastfm_top10_relabel.csv', index=False)
print("save lastfm_top10_relabel successfully")
# Out:
# 10 Jun 17:13    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'label']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 10 Jun 17:13    INFO  Load filtered dataset from: [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 17:13    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.39035486806188
# The number of items: 36078
# Average actions of items: 12.03647753416304
# The number of inters: 434240
# The sparsity of the dataset: 99.8631167529806%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 17:13    INFO  Load split dataloaders from: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 17:13    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 17:13    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 8793/8793 [00:00<00:00, 2624013.88it/s]
#                                     user_id gender  \
# 0  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d      M
# 1  715e75296006113fce5cb9a9a422228268d70a34      M
# 2  54df0a3d2814018201eae050559617b7c15860ab      M
# 3  5159f24173971f05fec1f19c9e1d08085de58c1e      F
# 4  0c28bcd3fa8cff593e6f8bea474e606233e23476      M
#
#                                           topk_items  \
# 0  cfbc0924-0035-4d6c-8197-f024653af823,f82bcf78-...
# 1  73e5e69d-3554-40d8-8516-00cb38737a1c,13655113-...
# 2  d96be5ad-ad54-47f4-8676-f1771026d120,4ccbc3e7-...
# 3  f82f3a3e-29c2-42ca-b589-bc5dc210fa9e,ada7a83c-...
# 4  cc197bad-dc9c-440d-a5b5-d52ba2e14234,b10bbbfc-...
#
#                                          topk_scores
# 0  9.9120,9.6598,9.6416,9.3764,9.3369,9.2641,8.89...
# 1  9.8596,9.1807,9.0020,8.8318,8.7293,8.6927,8.63...
# 2  8.7793,8.5365,8.4358,8.3247,8.1751,8.1424,8.06...
# 3  8.2267,7.3153,7.1840,7.1734,7.1319,7.0165,6.99...
# 4  8.3316,8.2216,8.0767,7.9532,7.8842,7.7576,7.52...
# user_id        8792
# gender            2
# topk_items     8791
# topk_scores    8792
# dtype: int64
# save lastfm_top10_relabel successfully
