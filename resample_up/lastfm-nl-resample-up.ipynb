# %%
# Apply fairness-aware data re-sampling (inspired by Ekstrand et al.) on lastfm-nl dataset for RecBole
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# 1. Load user profile, label interactions and plays interactions
user_df = pd.read_csv('../Post-processing/datasets/lastfm-nl/lastfm-nl.user', sep='\t')  # user_id:token, gender, age, etc.
inter_df_label = pd.read_csv('../datasets/split_datasets/lastfm-nl/lastfm-nl.train.inter', sep='\t')  # user_id:token, artist_id:token, label
inter_df_plays = pd.read_csv('../Post-processing/datasets/lastfm-nl/lastfm-nl.inter', sep='\t')  # user_id:token, artist_id:token, plays

# 2. Merge plays into train.inter
inter_df = inter_df_label.merge(
    inter_df_plays[['user_id:token', 'artist_id:token', 'plays:float']],
    how='left',
    left_on=['user_id:token', 'artist_id:token'],
    right_on=['user_id:token', 'artist_id:token']
)

# 3. Merge gender info
merged_df = inter_df.merge(
    user_df[['user_id:token', 'gender:token']],
    on='user_id:token',
    how='left'
)

merged_df.rename(columns={'gender:token': 'gender'}, inplace=True)

display(merged_df.head())
# Out:
#                               user_id:token  \
# 0  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 1  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 2  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 3  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
# 4  7db20cb306f5c6ee0a7da4b2eabbb12f80a4577d
#
#                         artist_id:token  label:float  plays:float gender
# 0  c7e90641-f441-4801-8e4a-d09e10f452b8          1.0          166      M
# 1  41489644-58f8-47e7-a581-e24d5659baeb          1.0          458      M
# 2  609e7afd-3552-4102-9501-7611858ea320          1.0          176      M
# 3  5251b5a0-3e3b-4d07-a152-585009575310          1.0          193      M
# 4  5f6ab597-f57a-40da-be9e-adad48708203          1.0          402      M

# %%
# 4. Check gender distribution
female_df = merged_df[merged_df['gender'] == 'F']
male_df = merged_df[merged_df['gender'] == 'M']

female_user_count = female_df['user_id:token'].nunique()
female_positive = female_df[female_df['label:float'] == 1]
female_negative = female_df[female_df['label:float'] == 0]
female_interactions = len(female_df)
print(f"Female users: {female_user_count}, Female interactions: {female_interactions}")
print(f"Female interactions per user: {female_interactions/female_user_count:.4f}")
print(f"Female positive interactions: {len(female_positive)}")
print(f"Female positive ratio: {len(female_positive) / female_interactions:.4f}")

male_user_count = male_df['user_id:token'].nunique()
male_positive = male_df[male_df['label:float'] == 1]
male_negative = male_df[male_df['label:float'] == 0]
male_interactions = len(male_df)
print(f"Male users: {male_user_count}, Male interactions: {male_interactions}")
print(f"Male interactions per user: {male_interactions/male_user_count:.4f}")
print(f"Male positive interactions: {len(male_positive)}")
print(f"Male positive ratio: {len(male_positive) / male_interactions:.4f}")
# Out:
# Female users: 1733, Female interactions: 69381
# Female interactions per user: 40.0352
# Female positive interactions: 68880
# Female positive ratio: 0.9928
# Male users: 7059, Male interactions: 287033
# Male interactions per user: 40.6620
# Male positive interactions: 285760
# Male positive ratio: 0.9956

# %%
# 5. Balance male/female interactions (upsample famale group)
upsample_amount = female_user_count * (male_interactions/male_user_count)
positive_diff = int(upsample_amount * (len(male_positive) / male_interactions) - len(female_positive))
negtive_diff = int(upsample_amount * (1 - len(male_positive) / male_interactions) - len(female_negative))
print("if upsample famale group:")
print(f"Need to add {upsample_amount - female_interactions:.0f} female interactions.")
print(f"Need to add {positive_diff} positive female interactions.")
print(f"Need to add {negtive_diff} negative female interactions.")
# Target female interaction count to match male ratio
# Get female user ids
female_users = female_df['user_id:token'].unique()
# Get all item ids
all_items = merged_df['artist_id:token'].unique()
female_all_items = female_df['artist_id:token'].unique()
male_al_item = female_df['artist_id:token'].unique()
# Create a set of existing (user, item) interactions for females
existing_pairs = set(zip(female_df['user_id:token'], female_df['artist_id:token']))

import random
random.seed(42)
new_positives = []
while len(new_positives) < positive_diff:
    user = random.choice(female_users, )
    item = random.choice(female_all_items)
    if (user, item) not in existing_pairs:
        new_positives.append({'user_id:token': user,
                              'artist_id:token': item,
                              'label:float': 1, 
                              'gender': 'F'})
        existing_pairs.add((user,item))
      
new_negatives = []
while len(new_negatives) < negtive_diff:
    user = random.choice(female_users)
    item = random.choice(male_al_item)
    if (user, item) not in existing_pairs:
        new_negatives.append({'user_id:token': user,
                              'item_id:token': item,
                              'label:float': 0, 
                              'gender': 'F'})
        existing_pairs.add((user,item))
       
new_samples = new_positives + new_negatives
# Create DataFrame and merge
df_fair = pd.concat([merged_df, pd.DataFrame(new_samples)], ignore_index=True)
# Out:
# if upsample famale group:
# Need to add 1086 female interactions.
# Need to add 1274 positive female interactions.
# Need to add -188 negative female interactions.

# %%
#shuffle balanced groups
df_fair = df_fair.sample(frac=1, random_state=42).reset_index(drop=True)

# 7. Optional: plot before and after
plt.figure(figsize=(8,4))
sns.histplot(data=merged_df, x="gender", stat="count", color="gray", label="Original", alpha=0.6)
sns.histplot(data=df_fair, x="gender", stat="count", color="blue", label="Fair-sampled", alpha=0.4)
plt.title("Gender Balance Before and After Re-sampling")
plt.legend()
plt.show()

display(df_fair.head())
# Out:
#                               user_id:token  \
# 0  43a22ad9b45b0cb5cf66a2819d4a4a9acf8efaaf
# 1  7aa203ef1b09ad10b7d09cfa2574ff60241eb42a
# 2  e8ff6610da153e6f13c7e0628d1b0a6b18c774d4
# 3  a25b555b92cc2186600873c8717035632abf3989
# 4  513b820264b6e23efbe48c8c3a80b359cfba72e8
#
#                         artist_id:token  label:float  plays:float gender
# 0  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d          1.0        512.0      M
# 1  34e10b51-b5c6-4bc1-b70e-f05f141eda1e          1.0         70.0      M
# 2  2f94cfb6-a425-48ca-8d8c-87a1f39d2952          1.0        195.0      M
# 3  a814e54f-1acb-43a2-ad15-a7f44b03879f          1.0        212.0      M
# 4  20aa23e3-3532-42ca-acf6-e8c2e9df2688          1.0        248.0      M

# %%
# 8. Save re-sampled interaction set
import os

save_path = 'datasets/lastfm-nl/lastfm-nl.train.inter'
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# 保存
df_fair[['user_id:token', 'artist_id:token','label:float']].to_csv(
    save_path,
    sep='\t',
    index=False
)
print(f"✅ Fair resampled dataset saved to {save_path}")
# Out:
# ✅ Fair resampled dataset saved to datasets/lastfm-nl/lastfm-nl.train.inter

# %%
import shutil

src_path = '../datasets/split_datasets/lastfm-nl/lastfm-nl.valid.inter'
dst_dir = 'datasets/lastfm-nl'
dst_path = os.path.join(dst_dir, 'lastfm-nl.valid.inter')

os.makedirs(dst_dir, exist_ok=True)

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")

src_path = '../datasets/split_datasets/lastfm-nl/lastfm-nl.test.inter'
dst_path = os.path.join(dst_dir, 'lastfm-nl.test.inter')

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")
# Out:
# ✅ File copied to datasets/lastfm-nl/lastfm-nl.valid.inter
# ✅ File copied to datasets/lastfm-nl/lastfm-nl.test.inter

# %%
from recbole.quick_start import run_recbole

run_recbole(config_file_list=['lastfm-nl-sample-up.yaml'])
# Out:
# 10 Jun 17:23    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-28459032-716a-48b0-8815-548a5349e7ac.json']
# 10 Jun 17:23    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'label']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 10 Jun 17:23    INFO  Saving filtered dataset into [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 17:23    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.5352593266606
# The number of items: 36078
# Average actions of items: 12.071790891703856
# The number of inters: 435514
# The sparsity of the dataset: 99.86271515649777%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 17:23    INFO  Saving split dataloaders into: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 17:23    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 17:23    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 10 Jun 17:23    INFO  BPR(
#   (user_embedding): Embedding(8793, 64)
#   (item_embedding): Embedding(36078, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 2871744
# 10 Jun 17:23    INFO  FLOPs: 128.0
# wandb: Currently logged in as: jiaqing61 (jiaqing61-tud) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/Users/huangjiaqing/Desktop/Recommender Systems/RScode/resample_up/wandb/run-20250610_172347-3e84ks6f</code>
# Syncing run <strong><a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/3e84ks6f' target="_blank">glamorous-eon-91</a></strong> to <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud</a>
#  View run at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/3e84ks6f' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/3e84ks6f</a>
# 10 Jun 17:23    INFO  epoch 0 training [time: 2.96s, train loss: 242.1800]
# 10 Jun 17:24    INFO  epoch 0 evaluating [time: 12.10s, valid_score: 0.029800]
# 10 Jun 17:24    INFO  valid result:
# precision@10 : 0.0159    recall@10 : 0.036    hit@10 : 0.1465    ndcg@10 : 0.0298    itemcoverage@10 : 0.0663    averagepopularity@10 : 1167.7461    shannonentropy@10 : 0.0013    giniindex@10 : 0.9977    tailpercentage@10 : 0.0038
# 10 Jun 17:24    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth
# 10 Jun 17:24    INFO  epoch 1 training [time: 3.07s, train loss: 203.9193]
# 10 Jun 17:24    INFO  epoch 1 evaluating [time: 12.32s, valid_score: 0.030600]
# 10 Jun 17:24    INFO  valid result:
# precision@10 : 0.016    recall@10 : 0.0363    hit@10 : 0.1467    ndcg@10 : 0.0306    itemcoverage@10 : 0.0109    averagepopularity@10 : 1242.3118    shannonentropy@10 : 0.0064    giniindex@10 : 0.9997    tailpercentage@10 : 0.0012
# 10 Jun 17:24    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth
# 10 Jun 17:24    INFO  epoch 2 training [time: 2.91s, train loss: 123.9227]
# 10 Jun 17:24    INFO  epoch 2 evaluating [time: 12.05s, valid_score: 0.031200]
# 10 Jun 17:24    INFO  valid result:
# precision@10 : 0.0163    recall@10 : 0.0369    hit@10 : 0.1498    ndcg@10 : 0.0312    itemcoverage@10 : 0.0081    averagepopularity@10 : 1242.0274    shannonentropy@10 : 0.0089    giniindex@10 : 0.9997    tailpercentage@10 : 0.0011
# 10 Jun 17:24    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth
# 10 Jun 17:24    INFO  epoch 3 training [time: 2.81s, train loss: 92.3299]
# 10 Jun 17:24    INFO  epoch 3 evaluating [time: 11.88s, valid_score: 0.032300]
# 10 Jun 17:24    INFO  valid result:
# precision@10 : 0.0173    recall@10 : 0.0391    hit@10 : 0.1581    ndcg@10 : 0.0323    itemcoverage@10 : 0.0081    averagepopularity@10 : 1215.7781    shannonentropy@10 : 0.0094    giniindex@10 : 0.9996    tailpercentage@10 : 0.001
# 10 Jun 17:24    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth
# 10 Jun 17:24    INFO  epoch 4 training [time: 2.71s, train loss: 80.2894]
# 10 Jun 17:25    INFO  epoch 4 evaluating [time: 12.00s, valid_score: 0.032700]
# 10 Jun 17:25    INFO  valid result:
# precision@10 : 0.0174    recall@10 : 0.0394    hit@10 : 0.16    ndcg@10 : 0.0327    itemcoverage@10 : 0.0088    averagepopularity@10 : 1215.9023    shannonentropy@10 : 0.0086    giniindex@10 : 0.9996    tailpercentage@10 : 0.0012
# 10 Jun 17:25    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth
# 10 Jun 17
kpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth
# 10 Jun 17:47    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     3.10 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.32 G/16.00 G |
# +-------------+----------------+
# 10 Jun 17:47    INFO  best valid : OrderedDict([('precision@10', 0.0347), ('recall@10', 0.0789), ('hit@10', 0.3015), ('ndcg@10', 0.0622), ('itemcoverage@10', 0.1525), ('averagepopularity@10', 575.4682), ('shannonentropy@10', 0.0011), ('giniindex@10', 0.9829), ('tailpercentage@10', 0.0109)])
# 10 Jun 17:47    INFO  test result: OrderedDict([('precision@10', 0.0343), ('recall@10', 0.0782), ('hit@10', 0.298), ('ndcg@10', 0.061), ('itemcoverage@10', 0.1525), ('averagepopularity@10', 575.4682), ('shannonentropy@10', 0.0011), ('giniindex@10', 0.9829), ('tailpercentage@10', 0.0109)])
# {'best_valid_score': 0.0622,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('precision@10', 0.0347),
#               ('recall@10', 0.0789),
#               ('hit@10', 0.3015),
#               ('ndcg@10', 0.0622),
#               ('itemcoverage@10', 0.1525),
#               ('averagepopularity@10', 575.4682),
#               ('shannonentropy@10', 0.0011),
#               ('giniindex@10', 0.9829),
#               ('tailpercentage@10', 0.0109)]),
#  'test_result': OrderedDict([('precision@10', 0.0343),
#               ('recall@10', 0.0782),
#               ('hit@10', 0.298),
#               ('ndcg@10', 0.061),
#               ('itemcoverage@10', 0.1525),
#               ('averagepopularity@10', 575.4682),
#               ('shannonentropy@10', 0.0011),
#               ('giniindex@10', 0.9829),
#               ('tailpercentage@10', 0.0109)])}

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd
import numpy as np

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_17-23-48.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series

uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=10, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]
score_lists = [row.cpu().tolist() for row in topk_scores]

# load gender information
user_df = pd.read_csv('../Post-processing/datasets/lastfm-nl/lastfm-nl.user', sep='\t')
user_df['user_id:token'] = user_df['user_id:token'].astype(str)
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'gender': [user2gender.get(uid, 'unknown') for uid in external_user_list],
    'topk_items': [','.join(items) for items in external_item_lists],
    'topk_scores': [','.join([f'{s:.4f}' for s in scores]) for scores in score_lists]
})
display(df.head())
print(df.nunique())
df.to_csv('../rank_results/lastfm-nl/lastfm_top10_resample_up.csv', index=False)
print("save lastfm_top10_resample_up successfully")
# Out:
# 10 Jun 17:48    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'label']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 10 Jun 17:48    INFO  Load filtered dataset from: [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 17:48    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.5352593266606
# The number of items: 36078
# Average actions of items: 12.071790891703856
# The number of inters: 435514
# The sparsity of the dataset: 99.86271515649777%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 17:48    INFO  Load split dataloaders from: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 17:48    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 17:48    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 8793/8793 [00:00<00:00, 2675991.52it/s]
#                                     user_id gender  \
# 0  43a22ad9b45b0cb5cf66a2819d4a4a9acf8efaaf      M
# 1  7aa203ef1b09ad10b7d09cfa2574ff60241eb42a      M
# 2  e8ff6610da153e6f13c7e0628d1b0a6b18c774d4      M
# 3  a25b555b92cc2186600873c8717035632abf3989      M
# 4  513b820264b6e23efbe48c8c3a80b359cfba72e8      M
#
#                                           topk_items  \
# 0  8ef1df30-ae4f-4dbd-9351-1a32b208a01e,b10bbbfc-...
# 1  b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d,d43d12a1-...
# 2  a74b1b7f-71a5-4011-9441-d0b5e4122711,056e4f3e-...
# 3  f4a31f0a-51dd-4fa7-986d-3095c40c5ed9,bc710bcf-...
# 4  66fc5bf8-daa4-4241-b378-9bc9077939d2,a74b1b7f-...
#
#                                          topk_scores
# 0  7.6723,7.5710,7.5176,7.4208,7.2103,7.1363,6.93...
# 1  8.4737,7.9379,7.6126,7.5096,7.4479,7.4300,7.32...
# 2  9.3953,8.5647,8.5551,8.4204,8.3500,8.2309,8.22...
# 3  9.2298,8.9611,8.8049,8.2849,7.9427,7.9208,7.86...
# 4  8.3807,8.3661,8.3603,8.3041,8.1792,7.9536,7.87...
# user_id        8792
# gender            2
# topk_items     8791
# topk_scores    8792
# dtype: int64
# save lastfm_top10_resample_up successfully
