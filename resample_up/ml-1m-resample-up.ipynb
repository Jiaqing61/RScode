# %% [markdown]
# # ml-1m

# %%
# Apply fairness-aware data re-sampling (inspired by Ekstrand et al.) on ml-1m dataset for RecBole
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# 1. Load user profile, label interactions and original atomic interactions
user_df = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.user', sep='\t')  # user_id:token, gender, age, etc.
inter_df_label = pd.read_csv('../datasets/split_datasets/ml-1m/ml-1m.train.inter', sep='\t')  # user_id:token, item_id:token, timestamp, label
inter_df_atomic = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.inter', sep='\t')  # user_id:token, item_id:token, rating, timestamp

# 2. Merge rating into train.inter
inter_df = inter_df_label.merge(
    inter_df_atomic[['user_id:token', 'item_id:token', 'rating:float']],
    how='left',
    left_on=['user_id:token', 'item_id:token'],
    right_on=['user_id:token', 'item_id:token']
)

# 3. Merge gender info
merged_df = inter_df.merge(
    user_df[['user_id:token', 'gender:token']],
    on='user_id:token',
    how='left'
)

merged_df.rename(columns={'gender:token': 'gender'}, inplace=True)

display(merged_df.head())
# Out:
#    user_id:token  item_id:token  timestamp:float  label:float  rating:float  \
# 0           1791           3949      974700700.0          1.0             4
# 1           1791           1084      974702340.0          1.0             3
# 2           1791           1805      974761150.0          0.0             2
# 3           1791           3897      974701200.0          1.0             4
# 4           1791           3741      974702400.0          1.0             4
#
#   gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M

# %%
# 4. Check gender distribution
female_df = merged_df[merged_df['gender'] == 'F']
male_df = merged_df[merged_df['gender'] == 'M']

female_user_count = female_df['user_id:token'].nunique()
female_positive = female_df[female_df['label:float'] == 1]
female_negative = female_df[female_df['label:float'] == 0]
female_interactions = len(female_df)
print(f"Female users: {female_user_count}, Female interactions: {female_interactions}")
print(f"Female interactions per user: {female_interactions/female_user_count:.4f}")
print(f"Female positive interactions: {len(female_positive)}")
print(f"Female positive ratio: {len(female_positive) / female_interactions:.4f}")

male_user_count = male_df['user_id:token'].nunique()
male_positive = male_df[male_df['label:float'] == 1]
male_negative = male_df[male_df['label:float'] == 0]
male_interactions = len(male_df)
print(f"Male users: {male_user_count}, Male interactions: {male_interactions}")
print(f"Male interactions per user: {male_interactions/male_user_count:.4f}")
print(f"Male positive interactions: {len(male_positive)}")
print(f"Male positive ratio: {len(male_positive) / male_interactions:.4f}")
# Out:
# Female users: 1709, Female interactions: 198620
# Female interactions per user: 116.2200
# Female positive interactions: 168129
# Female positive ratio: 0.8465
# Male users: 4331, Male interactions: 606823
# Male interactions per user: 140.1115
# Male positive interactions: 505428
# Male positive ratio: 0.8329

# %%
# 5. Balance male/female interactions (upsample famale group)
upsample_amount = female_user_count * (male_interactions/male_user_count)
positive_diff = int(upsample_amount * (len(male_positive) / male_interactions) - len(female_positive))
negtive_diff = int(upsample_amount * (1 - len(male_positive) / male_interactions) - len(female_negative))
print("if upsample famale group:")
print(f"Need to add {upsample_amount - female_interactions:.0f} female interactions.")
print(f"Need to add {positive_diff} positive female interactions.")
print(f"Need to add {negtive_diff} negative female interactions.")
# Target female interaction count to match male ratio
# Get female user ids
female_users = female_df['user_id:token'].unique()
# Get all item ids
all_items = merged_df['item_id:token'].unique()
female_all_items = female_df['item_id:token'].unique()
male_al_item = female_df['item_id:token'].unique()
# Create a set of existing (user, item) interactions for females
existing_pairs = set(zip(female_df['user_id:token'], female_df['item_id:token']))

import random
random.seed(42)
new_positives = []
while len(new_positives) < positive_diff:
    user = random.choice(female_users, )
    item = random.choice(female_all_items)
    if (user, item) not in existing_pairs:
        new_positives.append({'user_id:token': user,
                              'item_id:token': item,
                              'label:float': 1, 
                              'gender': 'F'})
        existing_pairs.add((user,item))
      
new_negatives = []
while len(new_negatives) < negtive_diff:
    user = random.choice(female_users)
    item = random.choice(male_al_item)
    if (user, item) not in existing_pairs:
        new_negatives.append({'user_id:token': user,
                              'item_id:token': item,
                              'label:float': 0, 
                              'gender': 'F'})
        existing_pairs.add((user,item))
       
new_samples = new_positives + new_negatives
# Create DataFrame and merge
df_fair = pd.concat([merged_df, pd.DataFrame(new_samples)], ignore_index=True)
# Out:
# if upsample famale group:
# Need to add 40831 female interactions.
# Need to add 31311 positive female interactions.
# Need to add 9519 negative female interactions.

# %%
#shuffle balanced groups
df_fair = df_fair.sample(frac=1, random_state=42).reset_index(drop=True)

# 7. Optional: plot before and after
plt.figure(figsize=(8,4))
sns.histplot(data=merged_df, x="gender", stat="count", color="gray", label="Original", alpha=0.6)
sns.histplot(data=df_fair, x="gender", stat="count", color="blue", label="Fair-sampled", alpha=0.4)
plt.title("Gender Balance Before and After Re-sampling")
plt.legend()
plt.show()

display(df_fair.head())
# Out:
#    user_id:token  item_id:token  timestamp:float  label:float  rating:float  \
# 0           2761           1910      973146700.0          1.0           4.0
# 1            904           1343      980206300.0          0.0           2.0
# 2           5100           3844      967806100.0          1.0           4.0
# 3           3051           3107      970205200.0          1.0           3.0
# 4            955            648      975210240.0          1.0           3.0
#
#   gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
# 8. Save re-sampled interaction set
import os

save_path = 'datasets/ml-1m/ml-1m.train.inter'
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# 保存
df_fair[['user_id:token', 'item_id:token', 'timestamp:float', 'label:float']].to_csv(
    save_path,
    sep='\t',
    index=False
)
print(f"✅ Fair resampled dataset saved to {save_path}")
# Out:
# ✅ Fair resampled dataset saved to datasets/ml-1m/ml-1m.train.inter

# %%
import shutil

src_path = '../datasets/split_datasets/ml-1m/ml-1m.valid.inter'
dst_dir = 'datasets/ml-1m'
dst_path = os.path.join(dst_dir, 'ml-1m.valid.inter')

os.makedirs(dst_dir, exist_ok=True)

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")

src_path = '../datasets/split_datasets/ml-1m/ml-1m.test.inter'
dst_path = os.path.join(dst_dir, 'ml-1m.test.inter')

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")
# Out:
# ✅ File copied to datasets/ml-1m/ml-1m.valid.inter
# ✅ File copied to datasets/ml-1m/ml-1m.test.inter

# %%
from recbole.quick_start import run_recbole

run_recbole(config_file_list=['ml-1m-resample-up.yaml'])
# Out:
# 10 Jun 21:48    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-581280d4-395d-45e7-8aeb-d01d02059ee1.json']
# 10 Jun 21:48    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'label', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 10 Jun 21:48    INFO  Load filtered dataset from: [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 10 Jun 21:48    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 172.35745033112582
# The number of items: 3707
# Average actions of items: 280.9063680518079
# The number of inters: 1041039
# The sparsity of the dataset: 95.35125656722047%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 10 Jun 21:48    INFO  Load split dataloaders from: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 10 Jun 21:48    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 21:48    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 10 Jun 21:48    INFO  BPR(
#   (user_embedding): Embedding(6041, 64)
#   (item_embedding): Embedding(3707, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 623872
# 10 Jun 21:48    INFO  FLOPs: 128.0
# wandb: Currently logged in as: jiaqing61 (jiaqing61-tud) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/Users/huangjiaqing/Desktop/Recommender Systems/RScode/resample_up/wandb/run-20250610_214848-e1r2dogj</code>
# Syncing run <strong><a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/e1r2dogj' target="_blank">rosy-waterfall-92</a></strong> to <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud</a>
#  View run at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/e1r2dogj' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/e1r2dogj</a>
# 10 Jun 21:48    INFO  epoch 0 training [time: 3.66s, train loss: 542.4476]
# 10 Jun 21:48    INFO  epoch 0 evaluating [time: 1.40s, valid_score: 0.055200]
# 10 Jun 21:48    INFO  valid result:
# precision@10 : 0.0439    recall@10 : 0.0447    hit@10 : 0.3435    ndcg@10 : 0.0552    itemcoverage@10 : 0.0612    averagepopularity@10 : 2216.1598    shannonentropy@10 : 0.0111    giniindex@10 : 0.9969    tailpercentage@10 : 0.0016
# 10 Jun 21:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:48    INFO  epoch 1 training [time: 3.40s, train loss: 366.9025]
# 10 Jun 21:48    INFO  epoch 1 evaluating [time: 1.37s, valid_score: 0.056500]
# 10 Jun 21:48    INFO  valid result:
# precision@10 : 0.0444    recall@10 : 0.0468    hit@10 : 0.3497    ndcg@10 : 0.0565    itemcoverage@10 : 0.0227    averagepopularity@10 : 2262.6457    shannonentropy@10 : 0.0285    giniindex@10 : 0.9972    tailpercentage@10 : 0.0007
# 10 Jun 21:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 2 training [time: 3.61s, train loss: 336.1449]
# 10 Jun 21:49    INFO  epoch 2 evaluating [time: 1.44s, valid_score: 0.059700]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.047    recall@10 : 0.05    hit@10 : 0.3629    ndcg@10 : 0.0597    itemcoverage@10 : 0.0272    averagepopularity@10 : 2216.4391    shannonentropy@10 : 0.0264    giniindex@10 : 0.9969    tailpercentage@10 : 0.0003
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 3 training [time: 3.41s, train loss: 320.5569]
# 10 Jun 21:49    INFO  epoch 3 evaluating [time: 1.41s, valid_score: 0.062000]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0494    recall@10 : 0.0518    hit@10 : 0.3783    ndcg@10 : 0.062    itemcoverage@10 : 0.038    averagepopularity@10 : 2169.5734    shannonentropy@10 : 0.0206    giniindex@10 : 0.9962    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 4 training [time: 5.82s, train loss: 307.2048]
# 10 Jun 21:49    INFO  epoch 4 evaluating [time: 1.53s, valid_score: 0.065000]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0517    recall@10 : 0.0542    hit@10 : 0.3967    ndcg@10 : 0.065    itemcoverage@10 : 0.0537    averagepopularity@10 : 2100.7179    shannonentropy@10 : 0.0164    giniindex@10 : 0.9946    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 5 training [time: 3.45s, train loss: 296.7388]
# 10 Jun 21:49    INFO  epoch 5 evaluating [time: 1.60s, valid_score: 0.066500]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0523    recall@10 : 0.0563    hit@10 : 0.3969    ndcg@10 : 0.0665    itemcoverage@10 : 0.0782    averagepopularity@10 : 2030.8262    shannonentropy@10 : 0.0121    giniindex@10 : 0.9928    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 6 training [time: 3.91s, train loss: 287.8073]
# 10 Jun 21:49    INFO  epoch 6 evaluating [time: 1.71s, valid_score: 0.068800]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0534    recall@10 : 0.0579    hit@10 : 0.4084    ndcg@10 : 0.0688    itemcoverage@10 : 0.0987    averagepopularity@10 : 1972.6875    shannonentropy@10 : 0.0102    giniindex@10 : 0.9908    tailpercentage@10 : 0.0002
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 7 training [time: 4.03s, train loss: 281.2030]
# 10 Jun 21:49    INFO  epoch 7 evaluating [time: 1.57s, valid_score: 0.070300]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0546    recall@10 : 0.0599    hit@10 : 0.4172    ndcg@10 : 0.0703    itemcoverage@10 : 0.1117    averagepopularity@10 : 1894.6488    shannonentropy@10 : 0.0096    giniindex@10 : 0.9882    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 8 training [time: 3.62s, train loss: 274.9380]
# 10 Jun 21:49    INFO  epoch 8 evaluating [time: 1.37s, valid_score: 0.071500]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0552    recall@10 : 0.0613    hit@10 : 0.4233    ndcg@10 : 0.0715    itemcoverage@10 : 0.1327    averagepopularity@10 : 1838.2729    shannonentropy@10 : 0.0085    giniindex@10 : 0.9852    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 9 training [time: 3.56s, train loss: 269.9550]
# 10 Jun 21:49    INFO  epoch 9 evaluating [time: 1.80s, valid_score: 0.072000]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0557    recall@10 : 0.0625    hit@10 : 0.426    ndcg@10 : 0.072    itemcoverage@10 : 0.1478    averagepopularity@10 : 1787.7701    shannonentropy@10 : 0.0079    giniindex@10 : 0.9823    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 10 training [time: 3.79s, train loss: 265.8154]
# 10 Jun 21:49    INFO  epoch 10 evaluating [time: 1.39s, valid_score: 0.072300]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0557    recall@10 : 0.0635    hit@10 : 0.4245    ndcg@10 : 0.0723    itemcoverage@10 : 0.1643    averagepopularity@10 : 1740.1824    shannonentropy@10 : 0.0074    giniindex@10 : 0.9793    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:49    INFO  epoch 11 training [time: 3.61s, train loss: 260.9556]
# 10 Jun 21:49    INFO  epoch 11 evaluating [time: 1.38s, valid_score: 0.072200]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0553    recall@10 : 0.0633    hit@10 : 0.4268    ndcg@10 : 0.0722    itemcoverage@10 : 0.1789    averagepopularity@10 : 1707.4382    shannonentropy@10 : 0.0069    giniindex@10 : 0.9776    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  epoch 12 training [time: 3.76s, train loss: 258.3175]
# 10 Jun 21:49    INFO  epoch 12 evaluating [time: 1.43s, valid_score: 0.074500]
# 10 Jun 21:49    INFO  valid result:
# precision@10 : 0.0572    recall@10 : 0.0656    hit@10 : 0.4376    ndcg@10 : 0.0745    itemcoverage@10 : 0.1886    averagepopularity@10 : 1683.1817    shannonentropy@10 : 0.0067    giniindex@10 : 0.9743    tailpercentage@10 : 0.0001
# 10 Jun 21:49    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:50    INFO  epoch 13 training [time: 3.62s, train loss: 255.0977]
# 10 Jun 21:50    INFO  epoch 13 evaluating [time: 1.41s, valid_score: 0.074200]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.057    recall@10 : 0.065    hit@10 : 0.4328    ndcg@10 : 0.0742    itemcoverage@10 : 0.1969    averagepopularity@10 : 1659.101    shannonentropy@10 : 0.0065    giniindex@10 : 0.9723    tailpercentage@10 : 0.0001
# 10 Jun 21:50    INFO  epoch 14 training [time: 3.38s, train loss: 252.6913]
# 10 Jun 21:50    INFO  epoch 14 evaluating [time: 1.36s, valid_score: 0.074100]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0573    recall@10 : 0.0662    hit@10 : 0.4343    ndcg@10 : 0.0741    itemcoverage@10 : 0.2077    averagepopularity@10 : 1635.2638    shannonentropy@10 : 0.0062    giniindex@10 : 0.9697    tailpercentage@10 : 0.0001
# 10 Jun 21:50    INFO  epoch 15 training [time: 3.96s, train loss: 249.3855]
# 10 Jun 21:50    INFO  epoch 15 evaluating [time: 1.52s, valid_score: 0.072700]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0569    recall@10 : 0.0653    hit@10 : 0.4353    ndcg@10 : 0.0727    itemcoverage@10 : 0.2255    averagepopularity@10 : 1600.2748    shannonentropy@10 : 0.0059    giniindex@10 : 0.9663    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  epoch 16 training [time: 3.41s, train loss: 247.0819]
# 10 Jun 21:50    INFO  epoch 16 evaluating [time: 1.38s, valid_score: 0.074000]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0577    recall@10 : 0.066    hit@10 : 0.4382    ndcg@10 : 0.074    itemcoverage@10 : 0.2333    averagepopularity@10 : 1583.1527    shannonentropy@10 : 0.0057    giniindex@10 : 0.9646    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  epoch 17 training [time: 4.37s, train loss: 244.0030]
# 10 Jun 21:50    INFO  epoch 17 evaluating [time: 1.50s, valid_score: 0.075200]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0582    recall@10 : 0.0676    hit@10 : 0.4419    ndcg@10 : 0.0752    itemcoverage@10 : 0.2476    averagepopularity@10 : 1554.0349    shannonentropy@10 : 0.0055    giniindex@10 : 0.9612    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:50    INFO  epoch 18 training [time: 3.62s, train loss: 241.5342]
# 10 Jun 21:50    INFO  epoch 18 evaluating [time: 1.37s, valid_score: 0.075800]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0582    recall@10 : 0.0685    hit@10 : 0.4427    ndcg@10 : 0.0758    itemcoverage@10 : 0.2574    averagepopularity@10 : 1517.9782    shannonentropy@10 : 0.0054    giniindex@10 : 0.9582    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:50    INFO  epoch 19 training [time: 4.01s, train loss: 239.0347]
# 10 Jun 21:50    INFO  epoch 19 evaluating [time: 1.42s, valid_score: 0.075800]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0583    recall@10 : 0.0693    hit@10 : 0.4457    ndcg@10 : 0.0758    itemcoverage@10 : 0.2684    averagepopularity@10 : 1496.8004    shannonentropy@10 : 0.0052    giniindex@10 : 0.9544    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:50    INFO  epoch 20 training [time: 3.64s, train loss: 236.8040]
# 10 Jun 21:50    INFO  epoch 20 evaluating [time: 1.42s, valid_score: 0.075700]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0586    recall@10 : 0.0693    hit@10 : 0.4411    ndcg@10 : 0.0757    itemcoverage@10 : 0.2795    averagepopularity@10 : 1481.2271    shannonentropy@10 : 0.0051    giniindex@10 : 0.9519    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  epoch 21 training [time: 3.51s, train loss: 234.8723]
# 10 Jun 21:50    INFO  epoch 21 evaluating [time: 1.43s, valid_score: 0.075400]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0582    recall@10 : 0.0691    hit@10 : 0.4411    ndcg@10 : 0.0754    itemcoverage@10 : 0.2884    averagepopularity@10 : 1469.7273    shannonentropy@10 : 0.005    giniindex@10 : 0.9494    tailpercentage@10 : 0.0001
# 10 Jun 21:50    INFO  epoch 22 training [time: 3.69s, train loss: 232.3936]
# 10 Jun 21:50    INFO  epoch 22 evaluating [time: 1.47s, valid_score: 0.075100]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0576    recall@10 : 0.0689    hit@10 : 0.4427    ndcg@10 : 0.0751    itemcoverage@10 : 0.2967    averagepopularity@10 : 1451.3694    shannonentropy@10 : 0.0049    giniindex@10 : 0.9475    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  epoch 23 training [time: 3.41s, train loss: 230.8120]
# 10 Jun 21:50    INFO  epoch 23 evaluating [time: 1.40s, valid_score: 0.076000]
# 10 Jun 21:50    INFO  valid result:
# precision@10 : 0.0581    recall@10 : 0.0698    hit@10 : 0.4467    ndcg@10 : 0.076    itemcoverage@10 : 0.3121    averagepopularity@10 : 1429.4727    shannonentropy@10 : 0.0047    giniindex@10 : 0.9433    tailpercentage@10 : 0.0002
# 10 Jun 21:50    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:50    INFO  epoch 24 training [time: 3.60s, train loss: 227.9018]
# 10 Jun 21:51    INFO  epoch 24 evaluating [time: 1.67s, valid_score: 0.075700]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0579    recall@10 : 0.07    hit@10 : 0.4462    ndcg@10 : 0.0757    itemcoverage@10 : 0.3199    averagepopularity@10 : 1420.3992    shannonentropy@10 : 0.0046    giniindex@10 : 0.9407    tailpercentage@10 : 0.0001
# 10 Jun 21:51    INFO  epoch 25 training [time: 3.79s, train loss: 225.2201]
# 10 Jun 21:51    INFO  epoch 25 evaluating [time: 1.40s, valid_score: 0.076000]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0578    recall@10 : 0.0701    hit@10 : 0.4447    ndcg@10 : 0.076    itemcoverage@10 : 0.3313    averagepopularity@10 : 1385.8051    shannonentropy@10 : 0.0045    giniindex@10 : 0.9364    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:51    INFO  epoch 26 training [time: 3.61s, train loss: 223.0851]
# 10 Jun 21:51    INFO  epoch 26 evaluating [time: 1.43s, valid_score: 0.076700]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0588    recall@10 : 0.0702    hit@10 : 0.4523    ndcg@10 : 0.0767    itemcoverage@10 : 0.3334    averagepopularity@10 : 1377.8907    shannonentropy@10 : 0.0045    giniindex@10 : 0.9344    tailpercentage@10 : 0.0001
# 10 Jun 21:51    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:51    INFO  epoch 27 training [time: 3.46s, train loss: 221.3682]
# 10 Jun 21:51    INFO  epoch 27 evaluating [time: 1.40s, valid_score: 0.075800]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.058    recall@10 : 0.0699    hit@10 : 0.4513    ndcg@10 : 0.0758    itemcoverage@10 : 0.3442    averagepopularity@10 : 1362.2888    shannonentropy@10 : 0.0044    giniindex@10 : 0.9319    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  epoch 28 training [time: 3.66s, train loss: 219.5271]
# 10 Jun 21:51    INFO  epoch 28 evaluating [time: 1.44s, valid_score: 0.075500]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0576    recall@10 : 0.0694    hit@10 : 0.4445    ndcg@10 : 0.0755    itemcoverage@10 : 0.3523    averagepopularity@10 : 1344.5209    shannonentropy@10 : 0.0043    giniindex@10 : 0.9303    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  epoch 29 training [time: 3.84s, train loss: 217.3054]
# 10 Jun 21:51    INFO  epoch 29 evaluating [time: 1.44s, valid_score: 0.076000]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0579    recall@10 : 0.0705    hit@10 : 0.4483    ndcg@10 : 0.076    itemcoverage@10 : 0.3639    averagepopularity@10 : 1340.7297    shannonentropy@10 : 0.0042    giniindex@10 : 0.927    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  epoch 30 training [time: 3.41s, train loss: 214.9715]
# 10 Jun 21:51    INFO  epoch 30 evaluating [time: 1.38s, valid_score: 0.075200]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0576    recall@10 : 0.0707    hit@10 : 0.4427    ndcg@10 : 0.0752    itemcoverage@10 : 0.3715    averagepopularity@10 : 1322.1977    shannonentropy@10 : 0.0042    giniindex@10 : 0.9246    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  epoch 31 training [time: 3.57s, train loss: 213.5279]
# 10 Jun 21:51    INFO  epoch 31 evaluating [time: 1.43s, valid_score: 0.074700]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0568    recall@10 : 0.0701    hit@10 : 0.4429    ndcg@10 : 0.0747    itemcoverage@10 : 0.3779    averagepopularity@10 : 1303.5144    shannonentropy@10 : 0.0041    giniindex@10 : 0.9225    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  epoch 32 training [time: 3.37s, train loss: 211.5362]
# 10 Jun 21:51    INFO  epoch 32 evaluating [time: 1.38s, valid_score: 0.075600]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0576    recall@10 : 0.0709    hit@10 : 0.4449    ndcg@10 : 0.0756    itemcoverage@10 : 0.3922    averagepopularity@10 : 1317.0605    shannonentropy@10 : 0.004    giniindex@10 : 0.9207    tailpercentage@10 : 0.0002
# 10 Jun 21:51    INFO  epoch 33 training [time: 3.47s, train loss: 209.3128]
# 10 Jun 21:51    INFO  epoch 33 evaluating [time: 1.38s, valid_score: 0.074900]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0574    recall@10 : 0.0708    hit@10 : 0.4425    ndcg@10 : 0.0749    itemcoverage@10 : 0.4038    averagepopularity@10 : 1301.4121    shannonentropy@10 : 0.0039    giniindex@10 : 0.9172    tailpercentage@10 : 0.0003
# 10 Jun 21:51    INFO  epoch 34 training [time: 3.33s, train loss: 207.7253]
# 10 Jun 21:51    INFO  epoch 34 evaluating [time: 1.40s, valid_score: 0.075200]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0569    recall@10 : 0.0701    hit@10 : 0.4425    ndcg@10 : 0.0752    itemcoverage@10 : 0.4157    averagepopularity@10 : 1284.3278    shannonentropy@10 : 0.0038    giniindex@10 : 0.9143    tailpercentage@10 : 0.0004
# 10 Jun 21:51    INFO  epoch 35 training [time: 4.47s, train loss: 205.7315]
# 10 Jun 21:51    INFO  epoch 35 evaluating [time: 1.36s, valid_score: 0.074300]
# 10 Jun 21:51    INFO  valid result:
# precision@10 : 0.0561    recall@10 : 0.0686    hit@10 : 0.4379    ndcg@10 : 0.0743    itemcoverage@10 : 0.4208    averagepopularity@10 : 1263.0166    shannonentropy@10 : 0.0038    giniindex@10 : 0.9111    tailpercentage@10 : 0.0003
# 10 Jun 21:51    INFO  epoch 36 training [time: 3.35s, train loss: 203.4734]
# 10 Jun 21:52    INFO  epoch 36 evaluating [time: 1.45s, valid_score: 0.074700]
# 10 Jun 21:52    INFO  valid result:
# precision@10 : 0.0568    recall@10 : 0.07    hit@10 : 0.4422    ndcg@10 : 0.0747    itemcoverage@10 : 0.4281    averagepopularity@10 : 1250.1601    shannonentropy@10 : 0.0037    giniindex@10 : 0.9095    tailpercentage@10 : 0.0004
# 10 Jun 21:52    INFO  epoch 37 training [time: 3.60s, train loss: 203.0579]
# 10 Jun 21:52    INFO  epoch 37 evaluating [time: 1.38s, valid_score: 0.074400]
# 10 Jun 21:52    INFO  valid result:
# precision@10 : 0.0564    recall@10 : 0.0696    hit@10 : 0.4455    ndcg@10 : 0.0744    itemcoverage@10 : 0.4365    averagepopularity@10 : 1241.9676    shannonentropy@10 : 0.0037    giniindex@10 : 0.9066    tailpercentage@10 : 0.0003
# 10 Jun 21:52    INFO  Finished training, best eval result in epoch 26
# 10 Jun 21:52    INFO  Loading model structure and parameters from checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth
# 10 Jun 21:52    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |    56.80 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.48 G/16.00 G |
# +-------------+----------------+
# 10 Jun 21:52    INFO  best valid : OrderedDict([('precision@10', 0.0588), ('recall@10', 0.0702), ('hit@10', 0.4523), ('ndcg@10', 0.0767), ('itemcoverage@10', 0.3334), ('averagepopularity@10', 1377.8907), ('shannonentropy@10', 0.0045), ('giniindex@10', 0.9344), ('tailpercentage@10', 0.0001)])
# 10 Jun 21:52    INFO  test result: OrderedDict([('precision@10', 0.0566), ('recall@10', 0.0697), ('hit@10', 0.4421), ('ndcg@10', 0.0731), ('itemcoverage@10', 0.3334), ('averagepopularity@10', 1377.8907), ('shannonentropy@10', 0.0045), ('giniindex@10', 0.9344), ('tailpercentage@10', 0.0001)])
# {'best_valid_score': 0.0767,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('precision@10', 0.0588),
#               ('recall@10', 0.0702),
#               ('hit@10', 0.4523),
#               ('ndcg@10', 0.0767),
#               ('itemcoverage@10', 0.3334),
#               ('averagepopularity@10', 1377.8907),
#               ('shannonentropy@10', 0.0045),
#               ('giniindex@10', 0.9344),
#               ('tailpercentage@10', 0.0001)]),
#  'test_result': OrderedDict([('precision@10', 0.0566),
#               ('recall@10', 0.0697),
#               ('hit@10', 0.4421),
#               ('ndcg@10', 0.0731),
#               ('itemcoverage@10', 0.3334),
#               ('averagepopularity@10', 1377.8907),
#               ('shannonentropy@10', 0.0045),
#               ('giniindex@10', 0.9344),
#               ('tailpercentage@10', 0.0001)])}

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd
import numpy as np

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='checkpoint_saved/ml-1m/BPR-Jun-10-2025_21-48-49.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series
uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=10, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]
score_lists = [row.cpu().tolist() for row in topk_scores]

# load gender information
user_df = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.user', sep='\t')
user_df['user_id:token'] = user_df['user_id:token'].astype(str)
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'gender': [user2gender.get(uid, 'unknown') for uid in external_user_list],
    'topk_items': [','.join(items) for items in external_item_lists],
    'topk_scores': [','.join([f'{s:.4f}' for s in scores]) for scores in score_lists]
})
display(df.head())
print(df.nunique())
df.to_csv('../rank_results/ml-1m/ml_top10_resample_up.csv', index=False)
print("save ml_top10_resample_up successfully")
# Out:
# 10 Jun 21:52    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'label', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 10 Jun 21:52    INFO  Load filtered dataset from: [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 10 Jun 21:52    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 172.35745033112582
# The number of items: 3707
# Average actions of items: 280.9063680518079
# The number of inters: 1041039
# The sparsity of the dataset: 95.35125656722047%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 10 Jun 21:52    INFO  Load split dataloaders from: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 10 Jun 21:52    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 21:52    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 6041/6041 [00:00<00:00, 2395329.03it/s]
#   user_id gender                                         topk_items  \
# 0    2761      M     1304,1580,1210,2916,1196,480,1610,780,1372,589
# 1     904      M  1974,1347,1321,1407,1994,3476,2867,2118,1645,1982
# 2    5100      M     1225,1230,1234,1097,924,919,1304,912,1193,1294
# 3    3051      M       2858,2571,70,2762,2959,480,223,589,1580,2028
# 4     955      F       3418,377,590,1094,21,2916,1396,608,2571,1183
#
#                                          topk_scores
# 0  4.1114,4.0075,3.9166,3.8934,3.8736,3.8399,3.82...
# 1  4.3433,4.3273,4.3150,4.3042,4.2897,4.2629,4.25...
# 2  2.9264,2.7942,2.6181,2.5840,2.5796,2.5663,2.51...
# 3  4.3593,4.2814,4.1646,4.1154,3.9496,3.9317,3.88...
# 4  3.0646,2.9270,2.8726,2.8241,2.7939,2.7805,2.77...
# user_id        6040
# gender            2
# topk_items     6040
# topk_scores    6040
# dtype: int64
# save ml_top10_resample_up successfully
