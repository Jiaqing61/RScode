# %%
import matplotlib.pyplot as plt
import seaborn as sns
from recbole.quick_start import run_recbole
import pandas as pd
from recbole.quick_start import load_data_and_model
import os

# %%
run_recbole(config_file_list=['lastfm-nl-relabel.yaml'])
# Out:
# 10 Jun 11:22    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-5bd9a9e6-bfd9-4349-bdbd-ebf8f43c98ad.json']
# 10 Jun 11:22    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = plays
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'plays': 2}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'plays']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 10 Jun 11:22    INFO  Saving filtered dataset into [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 11:22    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.39035486806188
# The number of items: 36078
# Average actions of items: 12.03647753416304
# The number of inters: 434240
# The sparsity of the dataset: 99.8631167529806%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 11:22    INFO  Saving split dataloaders into: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 11:22    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 11:22    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 10 Jun 11:22    INFO  BPR(
#   (user_embedding): Embedding(8793, 64)
#   (item_embedding): Embedding(36078, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 2871744
# 10 Jun 11:22    INFO  FLOPs: 128.0
# wandb: Currently logged in as: jiaqing61 (jiaqing61-tud) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/Users/huangjiaqing/Desktop/Recommender Systems/RScode/Post-processing/wandb/run-20250610_112249-kcxq746p</code>
# Syncing run <strong><a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/kcxq746p' target="_blank">royal-bird-82</a></strong> to <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud</a>
#  View run at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/kcxq746p' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/kcxq746p</a>
# 10 Jun 11:22    INFO  epoch 0 training [time: 2.75s, train loss: 241.4394]
# 10 Jun 11:23    INFO  epoch 0 evaluating [time: 12.88s, valid_score: 0.030700]
# 10 Jun 11:23    INFO  valid result:
# precision@10 : 0.0166    recall@10 : 0.0377    hit@10 : 0.1525    ndcg@10 : 0.0307    itemcoverage@10 : 0.0705    averagepopularity@10 : 1165.5967    shannonentropy@10 : 0.0013    giniindex@10 : 0.9974    tailpercentage@10 : 0.004
# 10 Jun 11:23    INFO  Saving current: checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_11-22-50.pth
# 10 Jun 11
# 10 Jun 11:39    INFO  epoch 72 training [time: 2.90s, train loss: 8.9614]
# 10 Jun 11:39    INFO  epoch 72 evaluating [time: 10.49s, valid_score: 0.061400]
# 10 Jun 11:39    INFO  valid result:
# precision@10 : 0.0342    recall@10 : 0.0779    hit@10 : 0.2966    ndcg@10 : 0.0614    itemcoverage@10 : 0.1175    averagepopularity@10 : 615.6316    shannonentropy@10 : 0.0014    giniindex@10 : 0.9879    tailpercentage@10 : 0.0056
# 10 Jun 11:39    INFO  epoch 73 training [time: 2.71s, train loss: 8.7306]
# 10 Jun 11:40    INFO  epoch 73 evaluating [time: 11.34s, valid_score: 0.061300]
# 10 Jun 11:40    INFO  valid result:
# precision@10 : 0.0341    recall@10 : 0.0778    hit@10 : 0.2949    ndcg@10 : 0.0613    itemcoverage@10 : 0.1202    averagepopularity@10 : 595.774    shannonentropy@10 : 0.0014    giniindex@10 : 0.9875    tailpercentage@10 : 0.0059
# 10 Jun 11:40    INFO  epoch 74 training [time: 2.68s, train loss: 8.7135]
# 10 Jun 11:40    INFO  epoch 74 evaluating [time: 11.56s, valid_score: 0.061800]
# 10 Jun 11:40    INFO  valid result:
# precision@10 : 0.0344    recall@10 : 0.0782    hit@10 : 0.298    ndcg@10 : 0.0618    itemcoverage@10 : 0.1225    averagepopularity@10 : 588.3229    shannonentropy@10 : 0.0013    giniindex@10 : 0.9872    tailpercentage@10 : 0.0061
# 10 Jun 11:40    INFO  epoch 75 training [time: 2.74s, train loss: 8.5214]
# 10 Jun 11:40    INFO  epoch 75 evaluating [time: 11.56s, valid_score: 0.062000]
# 10 Jun 11:40    INFO  valid result:
# precision@10 : 0.0347    recall@10 : 0.0791    hit@10 : 0.3011    ndcg@10 : 0.062    itemcoverage@10 : 0.1233    averagepopularity@10 : 578.2765    shannonentropy@10 : 0.0013    giniindex@10 : 0.987    tailpercentage@10 : 0.0063
# 10 Jun 11:40    INFO  epoch 76 training [time: 3.00s, train loss: 8.3270]
# 10 Jun 11:40    INFO  epoch 76 evaluating [time: 10.58s, valid_score: 0.061800]
# 10 Jun 11:40    INFO  valid result:
# precision@10 : 0.0346    recall@10 : 0.0787    hit@10 : 0.2988    ndcg@10 : 0.0618    itemcoverage@10 : 0.1252    averagepopularity@10 : 574.5843    shannonentropy@10 : 0.0013    giniindex@10 : 0.9868    tailpercentage@10 : 0.0065
# 10 Jun 11:40    INFO  Finished training, best eval result in epoch 65
# 10 Jun 11:40    INFO  Loading model structure and parameters from checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_11-22-50.pth
# 10 Jun 11:40    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     5.00 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.52 G/16.00 G |
# +-------------+----------------+
# 10 Jun 11:40    INFO  best valid : OrderedDict([('precision@10', 0.0344), ('recall@10', 0.0784), ('hit@10', 0.2987), ('ndcg@10', 0.0621), ('itemcoverage@10', 0.1021), ('averagepopularity@10', 631.3722), ('shannonentropy@10', 0.0016), ('giniindex@10', 0.9898), ('tailpercentage@10', 0.0041)])
# 10 Jun 11:40    INFO  test result: OrderedDict([('precision@10', 0.0332), ('recall@10', 0.0754), ('hit@10', 0.2904), ('ndcg@10', 0.0595), ('itemcoverage@10', 0.1021), ('averagepopularity@10', 631.3722), ('shannonentropy@10', 0.0016), ('giniindex@10', 0.9898), ('tailpercentage@10', 0.0041)])
# {'best_valid_score': 0.0621,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('precision@10', 0.0344),
#               ('recall@10', 0.0784),
#               ('hit@10', 0.2987),
#               ('ndcg@10', 0.0621),
#               ('itemcoverage@10', 0.1021),
#               ('averagepopularity@10', 631.3722),
#               ('shannonentropy@10', 0.0016),
#               ('giniindex@10', 0.9898),
#               ('tailpercentage@10', 0.0041)]),
#  'test_result': OrderedDict([('precision@10', 0.0332),
#               ('recall@10', 0.0754),
#               ('hit@10', 0.2904),
#               ('ndcg@10', 0.0595),
#               ('itemcoverage@10', 0.1021),
#               ('averagepopularity@10', 631.3722),
#               ('shannonentropy@10', 0.0016),
#               ('giniindex@10', 0.9898),
#               ('tailpercentage@10', 0.0041)])}

# %%
def save_interaction_for_training(inter_feat, dataset, save_path):
    df = {}
    for field in inter_feat.interaction.keys():
        if field == dataset.uid_field:
            df['user_id:token'] = dataset.id2token(field, inter_feat[field].numpy().tolist())
        elif field == dataset.iid_field:
            df['artist_id:token'] = dataset.id2token(field, inter_feat[field].numpy().tolist())
        elif field == config['LABEL_FIELD']:
            df['label:float'] = inter_feat[field].numpy()
        else:
            df[field] = inter_feat[field].numpy()
    pd.DataFrame(df).to_csv(save_path, sep='\t', index=False)

# 加载模型与数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_11-22-50.pth'
)

# 获取 interaction 对象
train_inter = train_data.dataset.inter_feat
valid_inter = valid_data.dataset.inter_feat
test_inter  = test_data.dataset.inter_feat

# 保存路径
save_dir = '../datasets/split_datasets/lastfm-nl'
os.makedirs(save_dir, exist_ok=True)

# 保存为 .inter 文件
save_interaction_for_training(train_inter, dataset, os.path.join(save_dir, 'lastfm-nl.train.inter'))
save_interaction_for_training(valid_inter, dataset, os.path.join(save_dir, 'lastfm-nl.valid.inter'))
save_interaction_for_training(test_inter, dataset, os.path.join(save_dir, 'lastfm-nl.test.inter'))
print("Train, valid, test datasets saved successfully.")
# Out:
# 10 Jun 11:42    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = plays
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'plays': 2}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'plays']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 10 Jun 11:42    INFO  Load filtered dataset from: [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 11:42    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.39035486806188
# The number of items: 36078
# Average actions of items: 12.03647753416304
# The number of inters: 434240
# The sparsity of the dataset: 99.8631167529806%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 11:42    INFO  Load split dataloaders from: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 11:42    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 11:42    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# Train, valid, test datasets saved successfully.

# %%
#save ground truth for test set based on rating
# Load test interactions (only positive labels)
test_df = pd.read_csv('../datasets/split_datasets/lastfm-nl/lastfm-nl.test.inter', sep='\t')
test_df = test_df[test_df['label:float'] == 1.0]

# Load plays info from original full inter dataset
plays_df = pd.read_csv('datasets/lastfm-nl/lastfm-nl.inter', sep='\t')
plays_df = plays_df[['user_id:token', 'artist_id:token', 'plays:float']]

# Merge plays into test positive interactions
test_df = test_df.merge(plays_df, on=['user_id:token', 'artist_id:token'], how='left')

# Sort each user's items by rating descending → more relevant items first
test_df.sort_values(['user_id:token', 'plays:float'], ascending=[True, False], inplace=True)

# Construct per-user ground-truth list (as comma-separated string) ===
# Format: user_id → 'item1,item2,item3,...'
ground_truth_df = test_df.groupby('user_id:token')['artist_id:token'].apply(
    lambda items: ','.join(map(str, items))
).reset_index()

ground_truth_df.columns = ['user_id', 'relevant_items_sorted_by_rating']

output_path = '../rank_results/lastfm-nl/lastfm_test_ground_truth_sorted.csv'
ground_truth_df.to_csv(output_path, index=False)

print(f"✅ Saved sorted ground-truth table to: {output_path}")
print(f"✅ Total users with ground truth: {len(ground_truth_df)}")
# Out:
# ✅ Saved sorted ground-truth table to: ../rank_results/lastfm-nl/ml_test_ground_truth_sorted.csv
# ✅ Total users with ground truth: 8769

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd
import numpy as np

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='checkpoint_saved/lastfm-nl/BPR-Jun-10-2025_11-22-50.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series

uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=50, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]
score_lists = [row.cpu().tolist() for row in topk_scores]

# load gender information
user_df = pd.read_csv('datasets/lastfm-nl/lastfm-nl.user', sep='\t')
user_df['user_id:token'] = user_df['user_id:token'].astype(str)
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'gender': [user2gender.get(uid, 'unknown') for uid in external_user_list],
    'topk_items': [','.join(items) for items in external_item_lists],
    'topk_scores': [','.join([f'{s:.4f}' for s in scores]) for scores in score_lists]
})
display(df.head())
print(df.nunique())
df.to_csv('../rank_results/lastfm-nl/lastfm_top50.csv', index=False)
print("save lastfm_top50 successfully")
# Out:
# 10 Jun 12:01    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/lastfm-nl
# checkpoint_dir = checkpoint_saved/lastfm-nl/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = artist_id
# RATING_FIELD = plays
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'plays': 2}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'artist_id', 'plays']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/lastfm-nl/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 10 Jun 12:01    INFO  Load filtered dataset from: [checkpoint_saved/lastfm-nl/lastfm-nl-Dataset.pth]
# 10 Jun 12:01    INFO  lastfm-nl
# The number of users: 8793
# Average actions of users: 49.39035486806188
# The number of items: 36078
# Average actions of items: 12.03647753416304
# The number of inters: 434240
# The sparsity of the dataset: 99.8631167529806%
# Remain Fields: ['user_id', 'artist_id', 'label']
# 10 Jun 12:01    INFO  Load split dataloaders from: [checkpoint_saved/lastfm-nl/lastfm-nl-for-BPR-dataloader.pth]
# 10 Jun 12:01    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 10 Jun 12:01    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 8793/8793 [00:00<00:00, 2705436.85it/s]
#                                     user_id gender  \
# 0  0004de6c3c32daa599bd03a37ce2356d5e7cc23f      M
# 1  0007e26aafcfc0b6dcb87d7041583fbb7cced88a      F
# 2  0009f70b52e48eca23a446d8a6f8bd2663691c54      F
# 3  001078f2f557a1afd9b9618144fc0b442481fd13      M
# 4  00292157f9c4e4b11464e886f27fff42f1ff442d      M
#
#                                           topk_items  \
# 0  31745282-b1ea-4d62-939f-226b14d68e7c,7fa7fc04-...
# 1  cc197bad-dc9c-440d-a5b5-d52ba2e14234,b10bbbfc-...
# 2  14b22b4b-06d5-4b82-8284-29d29b58945f,a505bb48-...
# 3  cc197bad-dc9c-440d-a5b5-d52ba2e14234,b10bbbfc-...
# 4  9a709693-b4f8-4da9-8cc1-038c911a61be,14b22b4b-...
#
#                                          topk_scores
# 0  8.1162,8.0042,7.8219,7.7762,7.7741,7.6109,7.52...
# 1  10.2432,9.7123,9.6197,9.4391,9.0732,9.0002,8.9...
# 2  8.0561,7.9366,7.5794,7.5463,7.3653,7.3006,7.27...
# 3  10.5511,10.3550,10.0145,9.8123,9.7214,9.5595,9...
# 4  7.7429,7.6171,7.5318,7.5233,7.4354,7.3395,7.27...
# user_id        8792
# gender            2
# topk_items     8792
# topk_scores    8792
# dtype: int64
# save lastfm_all_user_top50 successfully
