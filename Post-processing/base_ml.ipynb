# %%
import matplotlib.pyplot as plt
import seaborn as sns
from recbole.quick_start import run_recbole
from recbole.quick_start import load_data_and_model
import pandas as pd
import os

# %%
run_recbole(config_file_list=['ml-1m-base.yaml'])
# Out:
# 09 Jun 13:47    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-1b72226a-d083-47f9-b8b0-20d47af986df.json']
# 09 Jun 13:47    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'rating': 3}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 09 Jun 13:47    INFO  Saving filtered dataset into [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 13:47    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 13:47    INFO  Saving split dataloaders into: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 13:47    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 13:47    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 09 Jun 13:47    INFO  BPR(
#   (user_embedding): Embedding(6041, 64)
#   (item_embedding): Embedding(3707, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 623872
# 09 Jun 13:47    INFO  FLOPs: 128.0
# 09 Jun 13:47    INFO  epoch 0 training [time: 3.56s, train loss: 515.5253]
# 09 Jun 13:47    INFO  epoch 0 evaluating [time: 1.30s, valid_score: 0.055500]
# 09 Jun 13:47    INFO  valid result:
# precision@10 : 0.0441    recall@10 : 0.046    hit@10 : 0.3421    ndcg@10 : 0.0555    itemcoverage@10 : 0.0653    averagepopularity@10 : 2232.9562    shannonentropy@10 : 0.0103    giniindex@10 : 0.997    tailpercentage@10 : 0.0021
# 09 Jun 13:47    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:47    INFO  epoch 1 training [time: 3.34s, train loss: 334.5439]
# 09 Jun 13:47    INFO  epoch 1 evaluating [time: 1.32s, valid_score: 0.056900]
# 09 Jun 13:47    INFO  valid result:
# precision@10 : 0.0442    recall@10 : 0.0474    hit@10 : 0.3454    ndcg@10 : 0.0569    itemcoverage@10 : 0.024    averagepopularity@10 : 2214.2285    shannonentropy@10 : 0.0285    giniindex@10 : 0.9971    tailpercentage@10 : 0.0006
# 09 Jun 13:47    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:47    INFO  epoch 2 training [time: 3.52s, train loss: 301.8083]
# 09 Jun 13:47    INFO  epoch 2 evaluating [time: 1.29s, valid_score: 0.060100]
# 09 Jun 13:47    INFO  valid result:
# precision@10 : 0.0466    recall@10 : 0.0488    hit@10 : 0.3591    ndcg@10 : 0.0601    itemcoverage@10 : 0.0221    averagepopularity@10 : 2208.3601    shannonentropy@10 : 0.0318    giniindex@10 : 0.997    tailpercentage@10 : 0.0004
# 09 Jun 13:47    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 3 training [time: 3.29s, train loss: 287.6102]
# 09 Jun 13:48    INFO  epoch 3 evaluating [time: 1.29s, valid_score: 0.062200]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0489    recall@10 : 0.0526    hit@10 : 0.378    ndcg@10 : 0.0622    itemcoverage@10 : 0.0337    averagepopularity@10 : 2185.7441    shannonentropy@10 : 0.0228    giniindex@10 : 0.9964    tailpercentage@10 : 0.0004
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 4 training [time: 3.36s, train loss: 273.5997]
# 09 Jun 13:48    INFO  epoch 4 evaluating [time: 1.29s, valid_score: 0.064000]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0507    recall@10 : 0.055    hit@10 : 0.3927    ndcg@10 : 0.064    itemcoverage@10 : 0.0456    averagepopularity@10 : 2120.6542    shannonentropy@10 : 0.0186    giniindex@10 : 0.9953    tailpercentage@10 : 0.0002
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 5 training [time: 3.16s, train loss: 263.2354]
# 09 Jun 13:48    INFO  epoch 5 evaluating [time: 1.29s, valid_score: 0.065000]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0512    recall@10 : 0.0545    hit@10 : 0.3922    ndcg@10 : 0.065    itemcoverage@10 : 0.0612    averagepopularity@10 : 2053.5197    shannonentropy@10 : 0.0148    giniindex@10 : 0.994    tailpercentage@10 : 0.0003
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 6 training [time: 3.31s, train loss: 253.9159]
# 09 Jun 13:48    INFO  epoch 6 evaluating [time: 1.30s, valid_score: 0.068100]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0534    recall@10 : 0.0574    hit@10 : 0.4063    ndcg@10 : 0.0681    itemcoverage@10 : 0.0809    averagepopularity@10 : 2003.4012    shannonentropy@10 : 0.012    giniindex@10 : 0.9922    tailpercentage@10 : 0.0004
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 7 training [time: 3.16s, train loss: 247.0365]
# 09 Jun 13:48    INFO  epoch 7 evaluating [time: 1.31s, valid_score: 0.069400]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0539    recall@10 : 0.059    hit@10 : 0.4141    ndcg@10 : 0.0694    itemcoverage@10 : 0.1017    averagepopularity@10 : 1937.6025    shannonentropy@10 : 0.0102    giniindex@10 : 0.9899    tailpercentage@10 : 0.0002
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 8 training [time: 3.43s, train loss: 240.7789]
# 09 Jun 13:48    INFO  epoch 8 evaluating [time: 1.32s, valid_score: 0.070300]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0549    recall@10 : 0.061    hit@10 : 0.4169    ndcg@10 : 0.0703    itemcoverage@10 : 0.1155    averagepopularity@10 : 1879.2333    shannonentropy@10 : 0.0094    giniindex@10 : 0.9877    tailpercentage@10 : 0.0001
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 9 training [time: 3.33s, train loss: 234.9096]
# 09 Jun 13:48    INFO  epoch 9 evaluating [time: 1.30s, valid_score: 0.071400]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0555    recall@10 : 0.0618    hit@10 : 0.4195    ndcg@10 : 0.0714    itemcoverage@10 : 0.1338    averagepopularity@10 : 1806.107    shannonentropy@10 : 0.0085    giniindex@10 : 0.9845    tailpercentage@10 : 0.0001
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 10 training [time: 3.35s, train loss: 230.5225]
# 09 Jun 13:48    INFO  epoch 10 evaluating [time: 1.29s, valid_score: 0.071700]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0552    recall@10 : 0.0615    hit@10 : 0.4214    ndcg@10 : 0.0717    itemcoverage@10 : 0.1516    averagepopularity@10 : 1778.963    shannonentropy@10 : 0.0077    giniindex@10 : 0.9825    tailpercentage@10 : 0.0001
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 11 training [time: 3.21s, train loss: 226.7669]
# 09 Jun 13:48    INFO  epoch 11 evaluating [time: 1.36s, valid_score: 0.072600]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0564    recall@10 : 0.063    hit@10 : 0.4267    ndcg@10 : 0.0726    itemcoverage@10 : 0.1673    averagepopularity@10 : 1731.8583    shannonentropy@10 : 0.0072    giniindex@10 : 0.9795    tailpercentage@10 : 0.0001
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 12 training [time: 3.32s, train loss: 222.4556]
# 09 Jun 13:48    INFO  epoch 12 evaluating [time: 1.31s, valid_score: 0.072800]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0561    recall@10 : 0.0648    hit@10 : 0.4333    ndcg@10 : 0.0728    itemcoverage@10 : 0.178    averagepopularity@10 : 1674.2924    shannonentropy@10 : 0.007    giniindex@10 : 0.9763    tailpercentage@10 : 0.0
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 13 training [time: 3.19s, train loss: 219.4178]
# 09 Jun 13:48    INFO  epoch 13 evaluating [time: 1.31s, valid_score: 0.074500]
# 09 Jun 13:48    INFO  valid result:
# precision@10 : 0.0572    recall@10 : 0.0666    hit@10 : 0.4392    ndcg@10 : 0.0745    itemcoverage@10 : 0.1942    averagepopularity@10 : 1648.9792    shannonentropy@10 : 0.0065    giniindex@10 : 0.9739    tailpercentage@10 : 0.0001
# 09 Jun 13:48    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_13-47-44.pth
# 09 Jun 13:48    INFO  epoch 14 training [time: 3.38s, train loss: 216.8121]

# %%
def save_interaction_for_training(inter_feat, dataset, save_path):
    df = {}
    for field in inter_feat.interaction.keys():
        if field == dataset.uid_field:
            df['user_id:token'] = dataset.id2token(field, inter_feat[field].numpy().tolist())
        elif field == dataset.iid_field:
            df['item_id:token'] = dataset.id2token(field, inter_feat[field].numpy().tolist())
        elif field == config['TIME_FIELD']:
            df['timestamp:float'] = inter_feat[field].numpy()
        elif field == config['LABEL_FIELD']:
            df['label:float'] = inter_feat[field].numpy()
        else:
            df[field] = inter_feat[field].numpy()
    pd.DataFrame(df).to_csv(save_path, sep='\t', index=False)

# 加载模型与数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='../checkpoint_saved/ml-1m/BPR-Jun-09-2025_11-43-18.pth'
)

# 获取 interaction 对象
train_inter = train_data.dataset.inter_feat
valid_inter = valid_data.dataset.inter_feat
test_inter  = test_data.dataset.inter_feat

# 保存路径
save_dir = '../datasets/split_datasets/ml-1m'
os.makedirs(save_dir, exist_ok=True)

# 保存为 .inter 文件
save_interaction_for_training(train_inter, dataset, os.path.join(save_dir, 'ml-1m.train.inter'))
save_interaction_for_training(valid_inter, dataset, os.path.join(save_dir, 'ml-1m.valid.inter'))
save_interaction_for_training(test_inter, dataset, os.path.join(save_dir, 'ml-1m.test.inter'))
print("Train, valid, test datasets saved successfully.")
# Out:
# 09 Jun 13:42    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = ../checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'rating': 3}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = ../outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = ../outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 09 Jun 13:42    INFO  Load filtered dataset from: [../checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 13:42    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 13:42    INFO  Load split dataloaders from: [../checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 13:42    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 13:42    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# Train, valid, test datasets saved successfully.

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='../checkpoint_saved/ml-1m/BPR-Jun-09-2025_11-43-18.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series
import numpy as np
uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=50, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'topk_items': [','.join(items) for items in external_item_lists]
})
display(df.head())
df.to_csv('outputs/ml_all_user_top50.csv', index=False)
print("save ml_all_user_top50 successfully")
# Out:
# 09 Jun 13:43    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = ../checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'rating': 3}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = ../outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = ../outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 09 Jun 13:43    INFO  Load filtered dataset from: [../checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 13:43    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 13:43    INFO  Load split dataloaders from: [../checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 13:43    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 13:43    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 6041/6041 [00:00<00:00, 2854962.31it/s]
#   user_id                                         topk_items
# 0       1  2396,2858,919,34,1,1196,260,1097,3114,527,318,...
# 1       2  318,2028,3418,457,590,858,527,608,593,1610,110...
# 2       3  1196,1210,260,1580,1270,589,480,1197,1198,1291...
# 3       4  1196,260,1210,858,589,541,1214,1270,1240,1198,...
# 4       5  2908,2599,2333,3160,2692,2858,2997,2395,223,23...
# save ml_all_user_top50 successfully

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# Step 1: 加载推荐结果 & 用户性别
topk_df = pd.read_csv('outputs/ml_all_user_top10.csv')
user_df = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.user', sep='\t')
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 2: 加载测试集 ground truth（正反馈）
test_df = pd.read_csv('../datasets/split_datasets/ml-1m/ml-1m.test.inter', sep='\t')
test_df = test_df[test_df['label:float'] == 1.0]
user2ground_truth = test_df.groupby('user_id:token')['item_id:token'].agg(set).to_dict()

# Step 3: NDCG@10 计算函数
def ndcg_at_k(preds, true_items, k=10):
    dcg = 0.0
    for i, item in enumerate(preds[:k]):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)
    ideal_len = min(len(true_items), k)
    idcg = sum(1.0 / np.log2(i + 2) for i in range(ideal_len))
    return dcg / idcg if idcg > 0 else 0.0

# Step 4: 分组统计
ndcg_male, ndcg_female, ndcg_all = [], [], []

for _, row in topk_df.iterrows():
    uid = row['user_id']
    pred_items = eval(row['topk_items']) if isinstance(row['topk_items'], str) else row['topk_items']
    true_items = user2ground_truth.get(uid, set())
    gender = user2gender.get(uid, None)

    if gender not in ('M', 'F') or not true_items:
        continue

    ndcg = ndcg_at_k(pred_items, true_items, k=10)
    if gender == 'M':
        ndcg_male.append(ndcg)
        ndcg_all.append(ndcg)
    else:
        ndcg_female.append(ndcg)
        ndcg_all.append(ndcg)

# Step 5: 输出
print(f'NDCG@10 (All):    {np.mean(ndcg_all):.4f} over {len(ndcg_all)} users')
print(f'NDCG@10 (Male):   {np.mean(ndcg_male):.4f} over {len(ndcg_male)} users')
print(f'NDCG@10 (Female): {np.mean(ndcg_female):.4f} over {len(ndcg_female)} users')
# Out:
# NDCG@10 (All):    0.0769 over 6012 users
# NDCG@10 (Male):   0.0779 over 4312 users
# NDCG@10 (Female): 0.0743 over 1700 users
