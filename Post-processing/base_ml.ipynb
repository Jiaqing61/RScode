# %%
import matplotlib.pyplot as plt
import seaborn as sns
from recbole.quick_start import run_recbole
from recbole.quick_start import load_data_and_model
import pandas as pd
import os

# %%
run_recbole(config_file_list=['ml-1m-base.yaml'])
# Out:
# 09 Jun 14:16    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-aeaeb80f-1bbd-434a-93c0-ee934fd1d65b.json']
# 09 Jun 14:16    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'rating': 3}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 09 Jun 14:16    INFO  Saving filtered dataset into [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 14:16    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 14:16    INFO  Saving split dataloaders into: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 14:16    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 14:16    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 09 Jun 14:16    INFO  BPR(
#   (user_embedding): Embedding(6041, 64)
#   (item_embedding): Embedding(3707, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 623872
# 09 Jun 14:16    INFO  FLOPs: 128.0
# wandb: Currently logged in as: jiaqing61 (jiaqing61-tud) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/Users/huangjiaqing/Desktop/Recommender Systems/RScode/Post-processing/wandb/run-20250609_141630-1vvnjo9m</code>
# Syncing run <strong><a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/1vvnjo9m' target="_blank">peachy-dawn-76</a></strong> to <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud</a>
#  View run at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/1vvnjo9m' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/1vvnjo9m</a>
# 09 Jun 14:16    INFO  epoch 0 training [time: 3.10s, train loss: 515.5253]
# 09 Jun 14:16    INFO  epoch 0 evaluating [time: 1.35s, valid_score: 0.055500]
# 09 Jun 14:16    INFO  valid result:
# precision@10 : 0.0441    recall@10 : 0.046    hit@10 : 0.3421    ndcg@10 : 0.0555    itemcoverage@10 : 0.0653    averagepopularity@10 : 2232.9562    shannonentropy@10 : 0.0103    giniindex@10 : 0.997    tailpercentage@10 : 0.0021
# 09 Jun 14:16    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-16-30.pth
# 09 Jun 14:16    INFO  epoch 1 training [time: 3.07s, train loss: 334.5439]
# 09 Jun 14:16    INFO  epoch 1 evaluating [time: 1.34s, valid_score: 0.056900]
# 09 Jun 14:16    INFO  valid result:
# precision@10 : 0.0442    recall@10 : 0.0474    hit@10 : 0.3454    ndcg@10 : 0.0569    itemcoverage@10 : 0.024    averagepopularity@10 : 2214.2285    shannonentropy@10 : 0.0285    giniindex@10 : 0.9971    tailpercentage@10 : 0.0006
# 09 Jun 14:16    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-16-30.pth
# 09 Jun 14:16    INFO  epoch 2 training [time: 3.09s, train loss: 301.8083]
# 09 Jun 14:16    INFO  epoch 2 evaluating [time: 1.28s, valid_score: 0.060100]
# 09 Jun 14:16    INFO  valid result:
# precision@10 : 0.0466    recall@10 : 0.0488    hit@10 : 0.3591    ndcg@10 : 0.0601    itemcoverage@10 : 0.0221    averagepopularity@10 : 2208.3601    shannonentropy@10 : 0.0318    giniindex@10 : 0.997    tailpercentage@10 : 0.0004
# 09 Jun 14:16    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-16-30.pth
# 09 Jun 14:16    INFO  epoch 3 training [time: 2.95s, train loss: 287.6102]
# 09 Jun 14:16    INFO  epoch 3 evaluating [time: 1.34s, valid_score: 0.062200]
# 09 Jun 14:16    INFO  valid result:
# precision@10 : 0.0489    recall@10 : 0.0526    hit@10 : 0.378    ndcg@10 : 0.0622    itemcoverage@10 : 0.0337    averagepopularity@10 : 2185.7441    shannonentropy@10 : 0.0228    giniindex@10 : 0.9964    tailpercentage@10 : 0.0004
# 09 Jun 14:16    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-16-30.pth
# 09 Jun 14:16    INFO  epoch 4 training [time: 3.09s, train loss: 273.5997]
# 09 Jun 14:16    INFO  epoch 4 evaluating [time: 1.31s, valid_score: 0.064000]
# 09 Jun 14:16    INFO  valid result:
# precision@10 : 0.0507    recall@10 : 0.055    hit@10 : 0.3927    ndcg@10 : 0.064    itemcoverage@10 : 0.0456    averagepopularity@10 : 2120.6542    shannonentropy@10 : 0.0186    giniindex@10 : 0.9953    tailpercentage@10 : 0.0002
# 09 Jun 14:16    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-16-30.pth
# 09 Jun 14

# 09 Jun 14:19    INFO  valid result:
# precision@10 : 0.0575    recall@10 : 0.0725    hit@10 : 0.4447    ndcg@10 : 0.0761    itemcoverage@10 : 0.4413    averagepopularity@10 : 1245.1191    shannonentropy@10 : 0.0036    giniindex@10 : 0.9068    tailpercentage@10 : 0.0004
# 09 Jun 14:19    INFO  epoch 39 training [time: 3.50s, train loss: 172.8223]
# 09 Jun 14:19    INFO  epoch 39 evaluating [time: 1.59s, valid_score: 0.076600]
# 09 Jun 14:19    INFO  valid result:
# precision@10 : 0.0577    recall@10 : 0.0725    hit@10 : 0.4449    ndcg@10 : 0.0766    itemcoverage@10 : 0.4459    averagepopularity@10 : 1243.0678    shannonentropy@10 : 0.0036    giniindex@10 : 0.904    tailpercentage@10 : 0.0005
# 09 Jun 14:19    INFO  epoch 40 training [time: 3.41s, train loss: 170.6606]
# 09 Jun 14:19    INFO  epoch 40 evaluating [time: 1.47s, valid_score: 0.076300]
# 09 Jun 14:19    INFO  valid result:
# precision@10 : 0.0572    recall@10 : 0.0725    hit@10 : 0.4427    ndcg@10 : 0.0763    itemcoverage@10 : 0.4456    averagepopularity@10 : 1205.1873    shannonentropy@10 : 0.0036    giniindex@10 : 0.9014    tailpercentage@10 : 0.0004
# 09 Jun 14:20    INFO  epoch 41 training [time: 3.29s, train loss: 169.8232]
# 09 Jun 14:20    INFO  epoch 41 evaluating [time: 1.47s, valid_score: 0.076100]
# 09 Jun 14:20    INFO  valid result:
# precision@10 : 0.0572    recall@10 : 0.0726    hit@10 : 0.4401    ndcg@10 : 0.0761    itemcoverage@10 : 0.4543    averagepopularity@10 : 1189.2052    shannonentropy@10 : 0.0036    giniindex@10 : 0.8996    tailpercentage@10 : 0.0005
# 09 Jun 14:20    INFO  epoch 42 training [time: 4.01s, train loss: 168.6756]
# 09 Jun 14:20    INFO  epoch 42 evaluating [time: 1.59s, valid_score: 0.076000]
# 09 Jun 14:20    INFO  valid result:
# precision@10 : 0.0571    recall@10 : 0.0723    hit@10 : 0.4401    ndcg@10 : 0.076    itemcoverage@10 : 0.4594    averagepopularity@10 : 1184.3357    shannonentropy@10 : 0.0036    giniindex@10 : 0.8954    tailpercentage@10 : 0.0005
# 09 Jun 14:20    INFO  Finished training, best eval result in epoch 31
# 09 Jun 14:20    INFO  Loading model structure and parameters from checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-16-30.pth
# 09 Jun 14:20    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     9.30 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.72 G/16.00 G |
# +-------------+----------------+
# 09 Jun 14:20    INFO  best valid : OrderedDict([('precision@10', 0.0586), ('recall@10', 0.0728), ('hit@10', 0.4515), ('ndcg@10', 0.0777), ('itemcoverage@10', 0.375), ('averagepopularity@10', 1299.8173), ('shannonentropy@10', 0.0041), ('giniindex@10', 0.9234), ('tailpercentage@10', 0.0002)])
# 09 Jun 14:20    INFO  test result: OrderedDict([('precision@10', 0.058), ('recall@10', 0.0727), ('hit@10', 0.4478), ('ndcg@10', 0.076), ('itemcoverage@10', 0.375), ('averagepopularity@10', 1299.8173), ('shannonentropy@10', 0.0041), ('giniindex@10', 0.9234), ('tailpercentage@10', 0.0002)])
# {'best_valid_score': 0.0777,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('precision@10', 0.0586),
#               ('recall@10', 0.0728),
#               ('hit@10', 0.4515),
#               ('ndcg@10', 0.0777),
#               ('itemcoverage@10', 0.375),
#               ('averagepopularity@10', 1299.8173),
#               ('shannonentropy@10', 0.0041),
#               ('giniindex@10', 0.9234),
#               ('tailpercentage@10', 0.0002)]),
#  'test_result': OrderedDict([('precision@10', 0.058),
#               ('recall@10', 0.0727),
#               ('hit@10', 0.4478),
#               ('ndcg@10', 0.076),
#               ('itemcoverage@10', 0.375),
#               ('averagepopularity@10', 1299.8173),
#               ('shannonentropy@10', 0.0041),
#               ('giniindex@10', 0.9234),
#               ('tailpercentage@10', 0.0002)])}

# %%
def save_interaction_for_training(inter_feat, dataset, save_path):
    df = {}
    for field in inter_feat.interaction.keys():
        if field == dataset.uid_field:
            df['user_id:token'] = dataset.id2token(field, inter_feat[field].numpy().tolist())
        elif field == dataset.iid_field:
            df['item_id:token'] = dataset.id2token(field, inter_feat[field].numpy().tolist())
        elif field == config['TIME_FIELD']:
            df['timestamp:float'] = inter_feat[field].numpy()
        elif field == config['LABEL_FIELD']:
            df['label:float'] = inter_feat[field].numpy()
        else:
            df[field] = inter_feat[field].numpy()
    pd.DataFrame(df).to_csv(save_path, sep='\t', index=False)

# 加载模型与数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='../checkpoint_saved/ml-1m/BPR-Jun-09-2025_11-43-18.pth'
)

# 获取 interaction 对象
train_inter = train_data.dataset.inter_feat
valid_inter = valid_data.dataset.inter_feat
test_inter  = test_data.dataset.inter_feat

# 保存路径
save_dir = '../datasets/split_datasets/ml-1m'
os.makedirs(save_dir, exist_ok=True)

# 保存为 .inter 文件
save_interaction_for_training(train_inter, dataset, os.path.join(save_dir, 'ml-1m.train.inter'))
save_interaction_for_training(valid_inter, dataset, os.path.join(save_dir, 'ml-1m.valid.inter'))
save_interaction_for_training(test_inter, dataset, os.path.join(save_dir, 'ml-1m.test.inter'))
print("Train, valid, test datasets saved successfully.")
# Out:
# 09 Jun 14:25    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'rating': 3}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 09 Jun 14:25    INFO  Load filtered dataset from: [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 14:25    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 14:25    INFO  Load split dataloaders from: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 14:25    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 14:25    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# Train, valid, test datasets saved successfully.

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='../checkpoint_saved/ml-1m/BPR-Jun-09-2025_11-43-18.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series
import numpy as np
uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=50, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'topk_items': [','.join(items) for items in external_item_lists]
})
display(df.head())
df.to_csv('outputs/ml_all_user_top50.csv', index=False)
print("save ml_all_user_top50 successfully")
# Out:
# 09 Jun 14:25    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = {'rating': 3}
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'rating', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 09 Jun 14:25    INFO  Load filtered dataset from: [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 14:25    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 14:25    INFO  Load split dataloaders from: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 14:25    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 14:25    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 6041/6041 [00:00<00:00, 2913059.38it/s]
#   user_id                                         topk_items
# 0       1  595,34,364,919,1,588,2081,3114,318,594,1282,23...
# 1       2  2028,1183,590,3418,527,1610,318,349,608,1393,1...
# 2       3  1210,260,1196,1198,1270,480,356,1580,2716,110,...
# 3       4  1196,260,1210,1198,858,1214,1240,480,541,2028,...
# 4       5  2997,2692,2908,2858,2333,2599,2959,223,2395,23...
# save ml_all_user_top50 successfully

# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# Step 1: 加载推荐结果 & 用户性别
topk_df = pd.read_csv('outputs/ml_all_user_top10.csv')
user_df = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.user', sep='\t')
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 2: 加载测试集 ground truth（正反馈）
test_df = pd.read_csv('../datasets/split_datasets/ml-1m/ml-1m.test.inter', sep='\t')
test_df = test_df[test_df['label:float'] == 1.0]
user2ground_truth = test_df.groupby('user_id:token')['item_id:token'].agg(set).to_dict()

# Step 3: NDCG@10 计算函数
def ndcg_at_k(preds, true_items, k=10):
    dcg = 0.0
    for i, item in enumerate(preds[:k]):
        if item in true_items:
            dcg += 1.0 / np.log2(i + 2)
    ideal_len = min(len(true_items), k)
    idcg = sum(1.0 / np.log2(i + 2) for i in range(ideal_len))
    return dcg / idcg if idcg > 0 else 0.0

# Step 4: 分组统计
ndcg_male, ndcg_female, ndcg_all = [], [], []

for _, row in topk_df.iterrows():
    uid = row['user_id']
    pred_items = eval(row['topk_items']) if isinstance(row['topk_items'], str) else row['topk_items']
    true_items = user2ground_truth.get(uid, set())
    gender = user2gender.get(uid, None)

    if gender not in ('M', 'F') or not true_items:
        continue

    ndcg = ndcg_at_k(pred_items, true_items, k=10)
    if gender == 'M':
        ndcg_male.append(ndcg)
        ndcg_all.append(ndcg)
    else:
        ndcg_female.append(ndcg)
        ndcg_all.append(ndcg)

# Step 5: 输出
print(f'NDCG@10 (All):    {np.mean(ndcg_all):.4f} over {len(ndcg_all)} users')
print(f'NDCG@10 (Male):   {np.mean(ndcg_male):.4f} over {len(ndcg_male)} users')
print(f'NDCG@10 (Female): {np.mean(ndcg_female):.4f} over {len(ndcg_female)} users')
# Out:
# NDCG@10 (All):    0.0756 over 6012 users
# NDCG@10 (Male):   0.0770 over 4312 users
# NDCG@10 (Female): 0.0721 over 1700 users
