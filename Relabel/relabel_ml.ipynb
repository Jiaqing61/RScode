# %% [markdown]
# # ml-1m

# %%
# Apply fairness-aware data re-label (inspired by Kamiran et al.) on ml-1m dataset for RecBole
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# 1. Load user profile, label interactions and original atomic interactions
user_df = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.user', sep='\t')  # user_id:token, gender, age, etc.
inter_df_label = pd.read_csv('../datasets/split_datasets/ml-1m/ml-1m.train.inter', sep='\t')  # user_id:token, item_id:token, timestamp, label
inter_df_atomic = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.inter', sep='\t')  # user_id:token, item_id:token, rating, timestamp

# 2. Merge rating into train.inter
inter_df = inter_df_label.merge(
    inter_df_atomic[['user_id:token', 'item_id:token', 'rating:float']],
    how='left',
    left_on=['user_id:token', 'item_id:token'],
    right_on=['user_id:token', 'item_id:token']
)

# 3. Merge gender info
merged_df = inter_df.merge(
    user_df[['user_id:token', 'gender:token']],
    on='user_id:token',
    how='left'
)

merged_df.rename(columns={'gender:token': 'gender'}, inplace=True)

display(merged_df.head())
# Out:
#    user_id:token  item_id:token  timestamp:float  label:float  rating:float  \
# 0           1791           3949      974700700.0          1.0             4
# 1           1791           1084      974702340.0          1.0             3
# 2           1791           1805      974761150.0          0.0             2
# 3           1791           3897      974701200.0          1.0             4
# 4           1791           3741      974702400.0          1.0             4
#
#   gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M

# %%
# Count total users per gender (based on unique user-gender pairs)
user_gender_map = merged_df[['user_id:token', 'gender']].drop_duplicates()
gender_total = user_gender_map['gender'].value_counts().to_dict()
display(gender_total)
# Out:
# {'M': 4331, 'F': 1709}

# %%
# Total label=1 count per gender
print(f"Total interactions: {len(merged_df)}")
label_counts = merged_df['gender'].value_counts().to_dict()
display(label_counts)

# Compute global target ratio
target_ratio = merged_df['label:float'].mean()
print(f"\nGlobal target positive ratio (label==1): {target_ratio:.4f}")
# Out:
# Total interactions: 805443
# {'M': 606823, 'F': 198620}
# Global target positive ratio (label==1): 0.8363

# %%
label_1_counts = merged_df[merged_df['label:float'] == 1]['gender'].value_counts().to_dict()
current_male_1 = label_1_counts.get('M', 0)
current_female_1 = label_1_counts.get('F', 0)
# Compute target positive counts per gender group
target_male_1 = int(target_ratio * label_counts.get('M', 1))
target_female_1 = int(target_ratio * label_counts.get('F', 1))

flip_male_0_to_1 = max(0, target_male_1 - current_male_1)
flip_female_1_to_0 = max(0, current_female_1 - target_female_1)
print(f"  Target male label=1 count: {target_male_1}, current: {current_male_1}, {flip_male_0_to_1} to flip")
print(f"  Target female label=1 count: {target_female_1}, current: {current_female_1}, {flip_female_1_to_0} to flip")
# Out:
#   Target male label=1 count: 507459, current: 505428, 2031 to flip
#   Target female label=1 count: 166097, current: 168129, 2032 to flip

# %%
# Apply relabeling
# Flip female label=1 → 0
def flip_female_1_to_0(n):
    flipped = pd.Index([])
    for rating in [3, 4, 5]:
        candidates = merged_df[
            (merged_df['gender'] == 'F') &
            (merged_df['label:float'] == 1) &
            (merged_df['rating:float'] == rating) &
            (~merged_df.index.isin(flipped))
        ]
        to_flip = candidates.sample(n=min(n, len(candidates)), random_state=42)
        merged_df.loc[to_flip.index, 'label:float'] = 0
        flipped = flipped.union(to_flip.index)
        n -= len(to_flip)
        if n <= 0:
            break
    print(f"Flipped {len(flipped)} female label=1 → 0")

# Flip male label=0 → 1
def flip_male_0_to_1(n):
    flipped = pd.Index([])
    for rating in [2, 1]:
        candidates = merged_df[
            (merged_df['gender'] == 'M') &
            (merged_df['label:float'] == 0) &
            (merged_df['rating:float'] == rating) &
            (~merged_df.index.isin(flipped))
        ]
        to_flip = candidates.sample(n=min(n, len(candidates)), random_state=42)
        merged_df.loc[to_flip.index, 'label:float'] = 1
        flipped = flipped.union(to_flip.index)
        n -= len(to_flip)
        if n <= 0:
            break
    print(f"Flipped {len(flipped)} male label=0 → 1")
    
if current_female_1 > target_female_1:
    n = current_female_1 - target_female_1
    flip_female_1_to_0(n)

if current_male_1 < target_male_1:
    n = target_male_1 - current_male_1
    flip_male_0_to_1(n)    

result = merged_df.groupby('gender')['label:float'].value_counts(normalize=True).unstack()
print("\nFinal label==1 ratio by gender:")
print(result)
# Out:
# Flipped 2032 female label=1 → 0
# Flipped 2031 male label=0 → 1
#
# Final label==1 ratio by gender:
# label:float       0.0       1.0
# gender
# F            0.163745  0.836255
# M            0.163745  0.836255

# %%
# 8. Save re-sampled interaction set
import os

save_path = 'datasets/ml-1m/ml-1m.train.inter'
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# 保存
merged_df[['user_id:token', 'item_id:token', 'timestamp:float', 'label:float']].to_csv(
    save_path,
    sep='\t',
    index=False
)
print(f"✅ Fair resampled dataset saved to {save_path}")
# Out:
# ✅ Fair resampled dataset saved to datasets/ml-1m/ml-1m.train.inter

# %%
import shutil

src_path = '../datasets/split_datasets/ml-1m/ml-1m.valid.inter'
dst_dir = 'datasets/ml-1m'
dst_path = os.path.join(dst_dir, 'ml-1m.valid.inter')

os.makedirs(dst_dir, exist_ok=True)

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")

src_path = '../datasets/split_datasets/ml-1m/ml-1m.test.inter'
dst_path = os.path.join(dst_dir, 'ml-1m.test.inter')

# 复制文件
shutil.copyfile(src_path, dst_path)

print(f"✅ File copied to {dst_path}")
# Out:
# ✅ File copied to datasets/ml-1m/ml-1m.valid.inter
# ✅ File copied to datasets/ml-1m/ml-1m.test.inter

# %%
from recbole.quick_start import run_recbole

run_recbole(config_file_list=['ml-1m-relabel.yaml'])
# Out:
# 09 Jun 14:32    INFO  ['/Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/ipykernel_launcher.py', '-f', '/Users/huangjiaqing/Library/Jupyter/runtime/kernel-87e326ee-07dd-46f1-9597-fe4527b5d11b.json']
# 09 Jun 14:32    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'label', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:648: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=0, inplace=True)
# /Users/huangjiaqing/Desktop/Recommender Systems/RScode/.venv/lib/python3.10/site-packages/recbole/data/dataset/dataset.py:650: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feat[field].fillna(value=feat[field].mean(), inplace=True)
# 09 Jun 14:32    INFO  Saving filtered dataset into [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 14:32    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 14:32    INFO  Saving split dataloaders into: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 14:32    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 14:32    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 09 Jun 14:32    INFO  BPR(
#   (user_embedding): Embedding(6041, 64)
#   (item_embedding): Embedding(3707, 64)
#   (loss): BPRLoss()
# )
# Trainable parameters: 623872
# 09 Jun 14:32    INFO  FLOPs: 128.0
# wandb: Currently logged in as: jiaqing61 (jiaqing61-tud) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/Users/huangjiaqing/Desktop/Recommender Systems/RScode/Relabel/wandb/run-20250609_143209-oz07g09g</code>
# Syncing run <strong><a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/oz07g09g' target="_blank">astral-lake-77</a></strong> to <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud</a>
#  View run at <a href='https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/oz07g09g' target="_blank">https://wandb.ai/jiaqing61-tud/jiaqing61-tud/runs/oz07g09g</a>
# 09 Jun 14:32    INFO  epoch 0 training [time: 3.68s, train loss: 515.3208]
# 09 Jun 14:32    INFO  epoch 0 evaluating [time: 1.40s, valid_score: 0.056100]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0444    recall@10 : 0.0454    hit@10 : 0.344    ndcg@10 : 0.0561    itemcoverage@10 : 0.0513    averagepopularity@10 : 2218.9888    shannonentropy@10 : 0.0133    giniindex@10 : 0.997    tailpercentage@10 : 0.0017
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 1 training [time: 3.34s, train loss: 335.3148]
# 09 Jun 14:32    INFO  epoch 1 evaluating [time: 1.43s, valid_score: 0.058100]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.046    recall@10 : 0.0496    hit@10 : 0.3578    ndcg@10 : 0.0581    itemcoverage@10 : 0.0224    averagepopularity@10 : 2216.9502    shannonentropy@10 : 0.0321    giniindex@10 : 0.9969    tailpercentage@10 : 0.0007
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 2 training [time: 3.53s, train loss: 298.8576]
# 09 Jun 14:32    INFO  epoch 2 evaluating [time: 1.55s, valid_score: 0.060000]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0476    recall@10 : 0.0509    hit@10 : 0.3667    ndcg@10 : 0.06    itemcoverage@10 : 0.0272    averagepopularity@10 : 2186.3982    shannonentropy@10 : 0.0278    giniindex@10 : 0.9965    tailpercentage@10 : 0.0004
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 3 training [time: 3.35s, train loss: 282.0712]
# 09 Jun 14:32    INFO  epoch 3 evaluating [time: 1.40s, valid_score: 0.062800]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0499    recall@10 : 0.0528    hit@10 : 0.3843    ndcg@10 : 0.0628    itemcoverage@10 : 0.0424    averagepopularity@10 : 2146.2893    shannonentropy@10 : 0.019    giniindex@10 : 0.9959    tailpercentage@10 : 0.0004
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 4 training [time: 3.43s, train loss: 268.7013]
# 09 Jun 14:32    INFO  epoch 4 evaluating [time: 1.42s, valid_score: 0.064500]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0508    recall@10 : 0.0539    hit@10 : 0.3914    ndcg@10 : 0.0645    itemcoverage@10 : 0.0583    averagepopularity@10 : 2103.1183    shannonentropy@10 : 0.015    giniindex@10 : 0.9947    tailpercentage@10 : 0.0001
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 5 training [time: 3.45s, train loss: 258.9793]
# 09 Jun 14:32    INFO  epoch 5 evaluating [time: 1.38s, valid_score: 0.067200]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0529    recall@10 : 0.0566    hit@10 : 0.402    ndcg@10 : 0.0672    itemcoverage@10 : 0.0866    averagepopularity@10 : 2014.2986    shannonentropy@10 : 0.0111    giniindex@10 : 0.9924    tailpercentage@10 : 0.0002
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 6 training [time: 3.31s, train loss: 250.1903]
# 09 Jun 14:32    INFO  epoch 6 evaluating [time: 1.42s, valid_score: 0.068700]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0537    recall@10 : 0.0588    hit@10 : 0.4071    ndcg@10 : 0.0687    itemcoverage@10 : 0.0995    averagepopularity@10 : 1953.2294    shannonentropy@10 : 0.0103    giniindex@10 : 0.9902    tailpercentage@10 : 0.0002
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 7 training [time: 3.39s, train loss: 243.8072]
# 09 Jun 14:32    INFO  epoch 7 evaluating [time: 1.42s, valid_score: 0.069700]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0547    recall@10 : 0.0595    hit@10 : 0.4169    ndcg@10 : 0.0697    itemcoverage@10 : 0.1184    averagepopularity@10 : 1889.1865    shannonentropy@10 : 0.0091    giniindex@10 : 0.9878    tailpercentage@10 : 0.0001
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 8 training [time: 3.45s, train loss: 237.3024]
# 09 Jun 14:32    INFO  epoch 8 evaluating [time: 1.40s, valid_score: 0.071400]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0559    recall@10 : 0.0617    hit@10 : 0.4245    ndcg@10 : 0.0714    itemcoverage@10 : 0.1311    averagepopularity@10 : 1852.8763    shannonentropy@10 : 0.0084    giniindex@10 : 0.9859    tailpercentage@10 : 0.0001
# 09 Jun 14:32    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:32    INFO  epoch 9 training [time: 3.54s, train loss: 233.0436]
# 09 Jun 14:32    INFO  epoch 9 evaluating [time: 1.39s, valid_score: 0.071100]
# 09 Jun 14:32    INFO  valid result:
# precision@10 : 0.0551    recall@10 : 0.0616    hit@10 : 0.4225    ndcg@10 : 0.0711    itemcoverage@10 : 0.1427    averagepopularity@10 : 1795.5608    shannonentropy@10 : 0.0081    giniindex@10 : 0.9829    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  epoch 10 training [time: 3.30s, train loss: 228.9481]
# 09 Jun 14:33    INFO  epoch 10 evaluating [time: 1.43s, valid_score: 0.072600]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0566    recall@10 : 0.0634    hit@10 : 0.4275    ndcg@10 : 0.0726    itemcoverage@10 : 0.1554    averagepopularity@10 : 1739.7017    shannonentropy@10 : 0.0077    giniindex@10 : 0.9802    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 11 training [time: 3.57s, train loss: 225.1477]
# 09 Jun 14:33    INFO  epoch 11 evaluating [time: 1.42s, valid_score: 0.073500]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0572    recall@10 : 0.0652    hit@10 : 0.4368    ndcg@10 : 0.0735    itemcoverage@10 : 0.164    averagepopularity@10 : 1704.3223    shannonentropy@10 : 0.0075    giniindex@10 : 0.9773    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 12 training [time: 3.30s, train loss: 222.1699]
# 09 Jun 14:33    INFO  epoch 12 evaluating [time: 2.34s, valid_score: 0.073800]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.057    recall@10 : 0.0644    hit@10 : 0.4359    ndcg@10 : 0.0738    itemcoverage@10 : 0.1791    averagepopularity@10 : 1671.7514    shannonentropy@10 : 0.007    giniindex@10 : 0.9751    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 13 training [time: 3.68s, train loss: 218.8851]
# 09 Jun 14:33    INFO  epoch 13 evaluating [time: 1.62s, valid_score: 0.074500]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0573    recall@10 : 0.0653    hit@10 : 0.4384    ndcg@10 : 0.0745    itemcoverage@10 : 0.1994    averagepopularity@10 : 1628.46    shannonentropy@10 : 0.0065    giniindex@10 : 0.9719    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 14 training [time: 3.62s, train loss: 215.7792]
# 09 Jun 14:33    INFO  epoch 14 evaluating [time: 1.43s, valid_score: 0.074600]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0575    recall@10 : 0.0657    hit@10 : 0.4366    ndcg@10 : 0.0746    itemcoverage@10 : 0.2136    averagepopularity@10 : 1613.8354    shannonentropy@10 : 0.0061    giniindex@10 : 0.9697    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 15 training [time: 3.26s, train loss: 214.3877]
# 09 Jun 14:33    INFO  epoch 15 evaluating [time: 1.97s, valid_score: 0.073700]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0564    recall@10 : 0.0656    hit@10 : 0.4321    ndcg@10 : 0.0737    itemcoverage@10 : 0.222    averagepopularity@10 : 1585.0035    shannonentropy@10 : 0.006    giniindex@10 : 0.9664    tailpercentage@10 : 0.0002
# 09 Jun 14:33    INFO  epoch 16 training [time: 3.69s, train loss: 211.1008]
# 09 Jun 14:33    INFO  epoch 16 evaluating [time: 1.46s, valid_score: 0.073900]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0566    recall@10 : 0.0665    hit@10 : 0.4341    ndcg@10 : 0.0739    itemcoverage@10 : 0.2355    averagepopularity@10 : 1581.5127    shannonentropy@10 : 0.0057    giniindex@10 : 0.9644    tailpercentage@10 : 0.0002
# 09 Jun 14:33    INFO  epoch 17 training [time: 3.41s, train loss: 209.1747]
# 09 Jun 14:33    INFO  epoch 17 evaluating [time: 1.51s, valid_score: 0.076600]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0582    recall@10 : 0.0693    hit@10 : 0.4467    ndcg@10 : 0.0766    itemcoverage@10 : 0.2417    averagepopularity@10 : 1547.7769    shannonentropy@10 : 0.0056    giniindex@10 : 0.9612    tailpercentage@10 : 0.0002
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 18 training [time: 3.61s, train loss: 206.8542]
# 09 Jun 14:33    INFO  epoch 18 evaluating [time: 2.04s, valid_score: 0.077000]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0588    recall@10 : 0.0699    hit@10 : 0.4477    ndcg@10 : 0.077    itemcoverage@10 : 0.2611    averagepopularity@10 : 1549.8694    shannonentropy@10 : 0.0052    giniindex@10 : 0.9598    tailpercentage@10 : 0.0001
# 09 Jun 14:33    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:33    INFO  epoch 19 training [time: 3.78s, train loss: 203.7166]
# 09 Jun 14:33    INFO  epoch 19 evaluating [time: 1.41s, valid_score: 0.076200]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.0581    recall@10 : 0.0684    hit@10 : 0.4432    ndcg@10 : 0.0762    itemcoverage@10 : 0.2625    averagepopularity@10 : 1541.8998    shannonentropy@10 : 0.0052    giniindex@10 : 0.9581    tailpercentage@10 : 0.0002
# 09 Jun 14:33    INFO  epoch 20 training [time: 3.48s, train loss: 201.5006]
# 09 Jun 14:33    INFO  epoch 20 evaluating [time: 1.38s, valid_score: 0.074800]
# 09 Jun 14:33    INFO  valid result:
# precision@10 : 0.057    recall@10 : 0.0693    hit@10 : 0.4411    ndcg@10 : 0.0748    itemcoverage@10 : 0.2716    averagepopularity@10 : 1509.6618    shannonentropy@10 : 0.0051    giniindex@10 : 0.9548    tailpercentage@10 : 0.0002
# 09 Jun 14:33    INFO  epoch 21 training [time: 3.28s, train loss: 200.2885]
# 09 Jun 14:34    INFO  epoch 21 evaluating [time: 1.41s, valid_score: 0.077000]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0583    recall@10 : 0.0716    hit@10 : 0.4475    ndcg@10 : 0.077    itemcoverage@10 : 0.2889    averagepopularity@10 : 1469.1675    shannonentropy@10 : 0.0049    giniindex@10 : 0.9509    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:34    INFO  epoch 22 training [time: 3.43s, train loss: 198.0672]
# 09 Jun 14:34    INFO  epoch 22 evaluating [time: 1.40s, valid_score: 0.076400]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0581    recall@10 : 0.0712    hit@10 : 0.4475    ndcg@10 : 0.0764    itemcoverage@10 : 0.2959    averagepopularity@10 : 1461.0369    shannonentropy@10 : 0.0049    giniindex@10 : 0.9486    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  epoch 23 training [time: 3.43s, train loss: 195.9868]
# 09 Jun 14:34    INFO  epoch 23 evaluating [time: 1.39s, valid_score: 0.076600]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0577    recall@10 : 0.0707    hit@10 : 0.4439    ndcg@10 : 0.0766    itemcoverage@10 : 0.3081    averagepopularity@10 : 1455.5131    shannonentropy@10 : 0.0047    giniindex@10 : 0.9468    tailpercentage@10 : 0.0003
# 09 Jun 14:34    INFO  epoch 24 training [time: 3.27s, train loss: 194.3171]
# 09 Jun 14:34    INFO  epoch 24 evaluating [time: 1.44s, valid_score: 0.076500]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0581    recall@10 : 0.0718    hit@10 : 0.4482    ndcg@10 : 0.0765    itemcoverage@10 : 0.318    averagepopularity@10 : 1416.0918    shannonentropy@10 : 0.0046    giniindex@10 : 0.9423    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  epoch 25 training [time: 3.61s, train loss: 192.8944]
# 09 Jun 14:34    INFO  epoch 25 evaluating [time: 1.42s, valid_score: 0.076500]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0576    recall@10 : 0.0715    hit@10 : 0.4475    ndcg@10 : 0.0765    itemcoverage@10 : 0.3288    averagepopularity@10 : 1394.1078    shannonentropy@10 : 0.0045    giniindex@10 : 0.9382    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  epoch 26 training [time: 3.41s, train loss: 190.1467]
# 09 Jun 14:34    INFO  epoch 26 evaluating [time: 1.41s, valid_score: 0.075800]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0578    recall@10 : 0.0717    hit@10 : 0.4425    ndcg@10 : 0.0758    itemcoverage@10 : 0.3394    averagepopularity@10 : 1365.5368    shannonentropy@10 : 0.0044    giniindex@10 : 0.9355    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  epoch 27 training [time: 3.63s, train loss: 188.9988]
# 09 Jun 14:34    INFO  epoch 27 evaluating [time: 1.45s, valid_score: 0.076600]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0581    recall@10 : 0.072    hit@10 : 0.4475    ndcg@10 : 0.0766    itemcoverage@10 : 0.3461    averagepopularity@10 : 1368.6755    shannonentropy@10 : 0.0043    giniindex@10 : 0.9346    tailpercentage@10 : 0.0001
# 09 Jun 14:34    INFO  epoch 28 training [time: 3.33s, train loss: 187.2677]
# 09 Jun 14:34    INFO  epoch 28 evaluating [time: 1.48s, valid_score: 0.077300]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0589    recall@10 : 0.073    hit@10 : 0.453    ndcg@10 : 0.0773    itemcoverage@10 : 0.3547    averagepopularity@10 : 1366.3263    shannonentropy@10 : 0.0043    giniindex@10 : 0.9316    tailpercentage@10 : 0.0001
# 09 Jun 14:34    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:34    INFO  epoch 29 training [time: 3.70s, train loss: 185.2390]
# 09 Jun 14:34    INFO  epoch 29 evaluating [time: 1.49s, valid_score: 0.076900]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0582    recall@10 : 0.0727    hit@10 : 0.4472    ndcg@10 : 0.0769    itemcoverage@10 : 0.3612    averagepopularity@10 : 1348.0885    shannonentropy@10 : 0.0042    giniindex@10 : 0.9288    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  epoch 30 training [time: 3.29s, train loss: 184.3211]
# 09 Jun 14:34    INFO  epoch 30 evaluating [time: 1.41s, valid_score: 0.076700]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0578    recall@10 : 0.0734    hit@10 : 0.4445    ndcg@10 : 0.0767    itemcoverage@10 : 0.3693    averagepopularity@10 : 1333.8444    shannonentropy@10 : 0.0042    giniindex@10 : 0.926    tailpercentage@10 : 0.0003
# 09 Jun 14:34    INFO  epoch 31 training [time: 3.40s, train loss: 181.6744]
# 09 Jun 14:34    INFO  epoch 31 evaluating [time: 1.37s, valid_score: 0.076400]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0572    recall@10 : 0.0719    hit@10 : 0.4424    ndcg@10 : 0.0764    itemcoverage@10 : 0.3817    averagepopularity@10 : 1307.0336    shannonentropy@10 : 0.0041    giniindex@10 : 0.9228    tailpercentage@10 : 0.0003
# 09 Jun 14:34    INFO  epoch 32 training [time: 3.39s, train loss: 181.7280]
# 09 Jun 14:34    INFO  epoch 32 evaluating [time: 1.37s, valid_score: 0.075200]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0569    recall@10 : 0.0717    hit@10 : 0.4416    ndcg@10 : 0.0752    itemcoverage@10 : 0.3887    averagepopularity@10 : 1282.6364    shannonentropy@10 : 0.004    giniindex@10 : 0.9204    tailpercentage@10 : 0.0003
# 09 Jun 14:34    INFO  epoch 33 training [time: 3.28s, train loss: 180.0445]
# 09 Jun 14:34    INFO  epoch 33 evaluating [time: 1.41s, valid_score: 0.077300]
# 09 Jun 14:34    INFO  valid result:
# precision@10 : 0.0579    recall@10 : 0.073    hit@10 : 0.4474    ndcg@10 : 0.0773    itemcoverage@10 : 0.3976    averagepopularity@10 : 1276.8976    shannonentropy@10 : 0.004    giniindex@10 : 0.9162    tailpercentage@10 : 0.0002
# 09 Jun 14:34    INFO  Saving current: checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:35    INFO  epoch 34 training [time: 3.45s, train loss: 178.3078]
# 09 Jun 14:35    INFO  epoch 34 evaluating [time: 1.41s, valid_score: 0.076900]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0583    recall@10 : 0.0735    hit@10 : 0.4512    ndcg@10 : 0.0769    itemcoverage@10 : 0.4033    averagepopularity@10 : 1269.1445    shannonentropy@10 : 0.0039    giniindex@10 : 0.9143    tailpercentage@10 : 0.0003
# 09 Jun 14:35    INFO  epoch 35 training [time: 3.31s, train loss: 176.8118]
# 09 Jun 14:35    INFO  epoch 35 evaluating [time: 1.41s, valid_score: 0.076400]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0574    recall@10 : 0.073    hit@10 : 0.4477    ndcg@10 : 0.0764    itemcoverage@10 : 0.4138    averagepopularity@10 : 1252.8067    shannonentropy@10 : 0.0038    giniindex@10 : 0.9135    tailpercentage@10 : 0.0003
# 09 Jun 14:35    INFO  epoch 36 training [time: 3.42s, train loss: 175.8178]
# 09 Jun 14:35    INFO  epoch 36 evaluating [time: 1.39s, valid_score: 0.076800]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0573    recall@10 : 0.0722    hit@10 : 0.4462    ndcg@10 : 0.0768    itemcoverage@10 : 0.42    averagepopularity@10 : 1259.6449    shannonentropy@10 : 0.0038    giniindex@10 : 0.9114    tailpercentage@10 : 0.0003
# 09 Jun 14:35    INFO  epoch 37 training [time: 3.29s, train loss: 173.8691]
# 09 Jun 14:35    INFO  epoch 37 evaluating [time: 1.40s, valid_score: 0.076400]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0577    recall@10 : 0.0731    hit@10 : 0.4474    ndcg@10 : 0.0764    itemcoverage@10 : 0.4295    averagepopularity@10 : 1261.7572    shannonentropy@10 : 0.0037    giniindex@10 : 0.91    tailpercentage@10 : 0.0004
# 09 Jun 14:35    INFO  epoch 38 training [time: 3.41s, train loss: 173.0799]
# 09 Jun 14:35    INFO  epoch 38 evaluating [time: 1.38s, valid_score: 0.075300]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0567    recall@10 : 0.0719    hit@10 : 0.4435    ndcg@10 : 0.0753    itemcoverage@10 : 0.4324    averagepopularity@10 : 1225.6755    shannonentropy@10 : 0.0037    giniindex@10 : 0.9057    tailpercentage@10 : 0.0004
# 09 Jun 14:35    INFO  epoch 39 training [time: 3.26s, train loss: 172.5064]
# 09 Jun 14:35    INFO  epoch 39 evaluating [time: 1.38s, valid_score: 0.075100]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0569    recall@10 : 0.0723    hit@10 : 0.4427    ndcg@10 : 0.0751    itemcoverage@10 : 0.4438    averagepopularity@10 : 1210.5959    shannonentropy@10 : 0.0037    giniindex@10 : 0.9024    tailpercentage@10 : 0.0003
# 09 Jun 14:35    INFO  epoch 40 training [time: 3.41s, train loss: 170.1846]
# 09 Jun 14:35    INFO  epoch 40 evaluating [time: 1.38s, valid_score: 0.074600]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0564    recall@10 : 0.0725    hit@10 : 0.4407    ndcg@10 : 0.0746    itemcoverage@10 : 0.45    averagepopularity@10 : 1216.8031    shannonentropy@10 : 0.0036    giniindex@10 : 0.9025    tailpercentage@10 : 0.0003
# 09 Jun 14:35    INFO  epoch 41 training [time: 3.45s, train loss: 169.2173]
# 09 Jun 14:35    INFO  epoch 41 evaluating [time: 1.38s, valid_score: 0.074000]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0567    recall@10 : 0.072    hit@10 : 0.4399    ndcg@10 : 0.074    itemcoverage@10 : 0.4567    averagepopularity@10 : 1197.9245    shannonentropy@10 : 0.0036    giniindex@10 : 0.8995    tailpercentage@10 : 0.0004
# 09 Jun 14:35    INFO  epoch 42 training [time: 3.26s, train loss: 167.8801]
# 09 Jun 14:35    INFO  epoch 42 evaluating [time: 1.41s, valid_score: 0.074500]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0561    recall@10 : 0.0717    hit@10 : 0.4401    ndcg@10 : 0.0745    itemcoverage@10 : 0.4586    averagepopularity@10 : 1194.2203    shannonentropy@10 : 0.0036    giniindex@10 : 0.8977    tailpercentage@10 : 0.0004
# 09 Jun 14:35    INFO  epoch 43 training [time: 3.43s, train loss: 166.8514]
# 09 Jun 14:35    INFO  epoch 43 evaluating [time: 1.39s, valid_score: 0.075500]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0565    recall@10 : 0.0726    hit@10 : 0.4434    ndcg@10 : 0.0755    itemcoverage@10 : 0.4651    averagepopularity@10 : 1195.7902    shannonentropy@10 : 0.0035    giniindex@10 : 0.8952    tailpercentage@10 : 0.0004
# 09 Jun 14:35    INFO  epoch 44 training [time: 3.27s, train loss: 165.7505]
# 09 Jun 14:35    INFO  epoch 44 evaluating [time: 1.42s, valid_score: 0.073500]
# 09 Jun 14:35    INFO  valid result:
# precision@10 : 0.0552    recall@10 : 0.0706    hit@10 : 0.4351    ndcg@10 : 0.0735    itemcoverage@10 : 0.4723    averagepopularity@10 : 1187.5551    shannonentropy@10 : 0.0035    giniindex@10 : 0.8936    tailpercentage@10 : 0.0005
# 09 Jun 14:35    INFO  Finished training, best eval result in epoch 33
# 09 Jun 14:35    INFO  Loading model structure and parameters from checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth
# 09 Jun 14:35    INFO  The running environment of this training is as follows:
# +-------------+----------------+
# | Environment |     Usage      |
# +=============+================+
# | CPU         |     6.60 %     |
# +-------------+----------------+
# | GPU         |   0.0 / 0.0    |
# +-------------+----------------+
# | Memory      | 0.76 G/16.00 G |
# +-------------+----------------+
# 09 Jun 14:35    INFO  best valid : OrderedDict([('precision@10', 0.0579), ('recall@10', 0.073), ('hit@10', 0.4474), ('ndcg@10', 0.0773), ('itemcoverage@10', 0.3976), ('averagepopularity@10', 1276.8976), ('shannonentropy@10', 0.004), ('giniindex@10', 0.9162), ('tailpercentage@10', 0.0002)])
# 09 Jun 14:35    INFO  test result: OrderedDict([('precision@10', 0.0569), ('recall@10', 0.0713), ('hit@10', 0.4411), ('ndcg@10', 0.0736), ('itemcoverage@10', 0.3976), ('averagepopularity@10', 1276.8976), ('shannonentropy@10', 0.004), ('giniindex@10', 0.9162), ('tailpercentage@10', 0.0002)])
# {'best_valid_score': 0.0773,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('precision@10', 0.0579),
#               ('recall@10', 0.073),
#               ('hit@10', 0.4474),
#               ('ndcg@10', 0.0773),
#               ('itemcoverage@10', 0.3976),
#               ('averagepopularity@10', 1276.8976),
#               ('shannonentropy@10', 0.004),
#               ('giniindex@10', 0.9162),
#               ('tailpercentage@10', 0.0002)]),
#  'test_result': OrderedDict([('precision@10', 0.0569),
#               ('recall@10', 0.0713),
#               ('hit@10', 0.4411),
#               ('ndcg@10', 0.0736),
#               ('itemcoverage@10', 0.3976),
#               ('averagepopularity@10', 1276.8976),
#               ('shannonentropy@10', 0.004),
#               ('giniindex@10', 0.9162),
#               ('tailpercentage@10', 0.0002)])}

# %%
from recbole.quick_start import load_data_and_model
from recbole.utils.case_study import full_sort_topk
from tqdm import tqdm
import pandas as pd
import numpy as np

# 1. 加载模型和数据
config, model, dataset, train_data, valid_data, test_data = load_data_and_model(
    model_file='checkpoint_saved/ml-1m/BPR-Jun-09-2025_14-32-10.pth'
)

# Step 1: Get all internal user IDs
all_uids = list(range(dataset.user_num))

# Step 2: Filter out users who have no interactions in the test set
valid_uids = [uid for uid in tqdm(all_uids) if test_data.uid2history_item[uid] is not None]

# Step 3: Convert to Series
uid_series = np.array(valid_uids)

# Step 4: Run full_sort_topk
topk_scores, topk_index = full_sort_topk(uid_series, model, test_data, k=10, device=config['device'])

# Step 5: Convert internal item IDs to external tokens
external_item_lists = [dataset.id2token(dataset.iid_field, row.cpu().tolist()) for row in topk_index]
external_user_list = [dataset.id2token(dataset.uid_field, [uid])[0] for uid in uid_series]
score_lists = [row.cpu().tolist() for row in topk_scores]

# load gender information
user_df = pd.read_csv('../datasets/atomic_datasets/ml-1m/ml-1m.user', sep='\t')
user_df['user_id:token'] = user_df['user_id:token'].astype(str)
user2gender = dict(zip(user_df['user_id:token'], user_df['gender:token']))

# Step 6: Save as DataFrame
df = pd.DataFrame({
    'user_id': external_user_list,
    'gender': [user2gender.get(uid, 'unknown') for uid in external_user_list],
    'topk_items': [','.join(items) for items in external_item_lists],
    'topk_scores': [','.join([f'{s:.4f}' for s in scores]) for scores in score_lists]
})
display(df.head())
print(df.nunique())
df.to_csv('../rank_results/ml-1m/ml_top10_relabel.csv', index=False)
print("save ml_top10_relabel successfully")
# Out:
# 09 Jun 21:54    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 42
# state = INFO
# reproducibility = True
# data_path = datasets/ml-1m
# checkpoint_dir = checkpoint_saved/ml-1m/
# show_progress = False
# save_dataset = True
# dataset_save_path = None
# save_dataloaders = True
# dataloaders_save_path = None
# log_wandb = True
#
# Training Hyper Parameters:
# epochs = 100
# train_batch_size = 1024
# learner = adam
# learning_rate = 0.0005
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# repeatable = True
# metrics = ['Precision', 'Recall', 'Hit', 'NDCG', 'ItemCoverage', 'AveragePopularity', 'ShannonEntropy', 'GiniIndex', 'TailPercentage']
# topk = [10]
# valid_metric = NDCG@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'label', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [0,inf)
# item_inter_num_interval = [0,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = ['train', 'valid', 'test']
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = jiaqing61-tud
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# workers = 2
# encoding = utf-8
# output_path = outputs/results/ml-1m/
# wandb_path = outputs/
# wandb_run_id = None
# wandb_run_name = None
# date = None
# timestamp = None
# log_root = outputs/logs/
# skip_test = False
# tail_ratio = 0.2
# reg_weight = 0.0003
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# device = cpu
# valid_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
# test_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# 09 Jun 21:54    INFO  Load filtered dataset from: [checkpoint_saved/ml-1m/ml-1m-Dataset.pth]
# 09 Jun 21:54    INFO  ml-1m
# The number of users: 6041
# Average actions of users: 165.5975165562914
# The number of items: 3707
# Average actions of items: 269.88909875876953
# The number of inters: 1000209
# The sparsity of the dataset: 95.53358229599758%
# Remain Fields: ['user_id', 'item_id', 'timestamp', 'label']
# 09 Jun 21:55    INFO  Load split dataloaders from: [checkpoint_saved/ml-1m/ml-1m-for-BPR-dataloader.pth]
# 09 Jun 21:55    INFO  [Training]: train_batch_size = [1024] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# 09 Jun 21:55    INFO  [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [0.8, 0.1, 0.1]}, 'order': 'RO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}]
# 100%|██████████| 6041/6041 [00:00<00:00, 2506706.61it/s]
#   user_id gender                                         topk_items  \
# 0    1791      M     162,1248,3683,750,296,1617,1089,1213,2912,1228
# 1    2496      M   2454,1334,2664,1214,1327,3471,2648,1387,924,2455
# 2    2718      F             539,356,1,34,588,1265,2424,364,1721,11
# 3    4089      M  1961,2420,3578,3448,1968,1721,2003,3785,2918,3753
# 4    1484      M        162,1732,296,1617,2289,2997,50,800,1213,778
#
#                                          topk_scores
# 0  4.7778,4.5798,4.4481,4.4307,4.3763,4.3295,4.31...
# 1  4.0958,3.9444,3.9265,3.8185,3.7686,3.7665,3.75...
# 2  4.2370,4.1640,4.1529,4.1155,4.1095,4.0192,4.01...
# 3  3.3054,3.2585,3.2338,3.2187,3.2065,3.1450,3.13...
# 4  3.9110,3.7895,3.7782,3.7465,3.7355,3.7107,3.70...
# user_id        6040
# gender            2
# topk_items     6040
# topk_scores    6040
# dtype: int64
# save ml_top10_relabel successfully
